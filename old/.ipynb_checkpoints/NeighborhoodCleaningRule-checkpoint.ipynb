# %%
import numpy as np 
import matplotlib.pyplot as plt 
import os
from PIL import Image
print(os.listdir("./common/data"))

import tensorflow as tf


config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
tf.compat.v1.keras.backend.set_session(tf.compat.v1.Session(config=config))

# Keras Libraries
import keras
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator, load_img
from sklearn.metrics import classification_report, confusion_matrix
# %matplotlib inline
# Out:
# ['chest_xray', 'resampled', 'TEST']
# Using TensorFlow backend.

# %% [markdown]
# # Resample Data Into New Dataset

# %% [markdown]
# # Resample Train Data

# %%
from common.src import resample as res

# %%
from imblearn.under_sampling import NeighbourhoodCleaningRule

path = r'C:\Users\mmitk\dev\2020\pneumonia\common\data\chest_xray\train'
ncr = NeighbourhoodCleaningRule()

# %%
res.resample_directory(ncr, path, 'NeighborhoodCleaningRule', val = False)

# %% [markdown]
# # Load Data

# %%
train_folder= './common/data/resampled/NeighborhoodCleaningRule/train'
val_folder = './common/data/chest_xray/val/'
test_folder = './common/data/chest_xray/test/'

# %%
# train 
os.listdir(train_folder)
train_n = train_folder+'NORMAL/'
train_p = train_folder+'PNEUMONIA/'

# %%
# test
os.listdir(test_folder)
train_n = test_folder+'NORMAL/'
train_p = test_folder+'PNEUMONIA/'

# %%
from common.src import util

train_datagen = util.create_train_datagen()
test_datagen = util.create_test_datagen()

training_set = util.create_generator_set(train_datagen, './common/data/resampled/NeighborhoodCleaningRule/train')
validation_generator = util.create_generator_set(test_datagen, './common/data/chest_xray/val/')
test_set = util.create_generator_set(test_datagen, './common/data/chest_xray/test/', batch_size = 1, shuffle = False)
# Out:
# Found 4809 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %% [markdown]
# # Create Model

# %%
from common.src import models

cnn = models.CNNModel(patience_s = 19)
cnn.create_model()
cnn.summary()

# %% [markdown]
# # Fit Model

# %%
cnn_model = cnn.fit_generator(training_set, validation_generator, epochs=20)
# Out:
# Epoch 1/20
# 163/163 [==============================] - 12s 77ms/step - loss: 0.3676 - tp: 4334.0000 - fp: 862.0000 - tn: 4331.0000 - fn: 859.0000 - accuracy: 0.8343 - precision: 0.8341 - recall: 0.8346 - auc: 0.9148 - val_loss: 0.4475 - val_tp: 228.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 76.0000 - val_accuracy: 0.7812 - val_precision: 0.8000 - val_recall: 0.7500 - val_auc: 0.8867
# Epoch 2/20
# 163/163 [==============================] - 10s 61ms/step - loss: 0.2320 - tp: 4666.0000 - fp: 499.0000 - tn: 4671.0000 - fn: 504.0000 - accuracy: 0.9030 - precision: 0.9034 - recall: 0.9025 - auc: 0.9672 - val_loss: 0.3399 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9258
# Epoch 3/20
# 163/163 [==============================] - 10s 61ms/step - loss: 0.1962 - tp: 4804.0000 - fp: 417.0000 - tn: 4799.0000 - fn: 412.0000 - accuracy: 0.9205 - precision: 0.9201 - recall: 0.9210 - auc: 0.9764 - val_loss: 0.4406 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8633
# Epoch 4/20
# 163/163 [==============================] - 10s 61ms/step - loss: 0.1748 - tp: 4838.0000 - fp: 347.0000 - tn: 4846.0000 - fn: 355.0000 - accuracy: 0.9324 - precision: 0.9331 - recall: 0.9316 - auc: 0.9810 - val_loss: 0.6037 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8105
# Epoch 5/20
# 163/163 [==============================] - 10s 61ms/step - loss: 0.1732 - tp: 4847.0000 - fp: 347.0000 - tn: 4846.0000 - fn: 346.0000 - accuracy: 0.9333 - precision: 0.9332 - recall: 0.9334 - auc: 0.9816 - val_loss: 0.6434 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8320
# Epoch 6/20
# 163/163 [==============================] - 10s 62ms/step - loss: 0.1489 - tp: 4898.0000 - fp: 298.0000 - tn: 4895.0000 - fn: 295.0000 - accuracy: 0.9429 - precision: 0.9426 - recall: 0.9432 - auc: 0.9860 - val_loss: 0.2573 - val_tp: 266.0000 - val_fp: 19.0000 - val_tn: 285.0000 - val_fn: 38.0000 - val_accuracy: 0.9062 - val_precision: 0.9333 - val_recall: 0.8750 - val_auc: 0.9648
# Epoch 7/20
# 163/163 [==============================] - 10s 61ms/step - loss: 0.1446 - tp: 4903.0000 - fp: 271.0000 - tn: 4899.0000 - fn: 267.0000 - accuracy: 0.9480 - precision: 0.9476 - recall: 0.9484 - auc: 0.9868 - val_loss: 0.5526 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8555
# Epoch 8/20
# 163/163 [==============================] - 10s 62ms/step - loss: 0.1342 - tp: 4912.0000 - fp: 284.0000 - tn: 4909.0000 - fn: 281.0000 - accuracy: 0.9456 - precision: 0.9453 - recall: 0.9459 - auc: 0.9885 - val_loss: 0.2315 - val_tp: 285.0000 - val_fp: 19.0000 - val_tn: 285.0000 - val_fn: 19.0000 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9902
# Epoch 9/20
# 163/163 [==============================] - 10s 61ms/step - loss: 0.1247 - tp: 4958.0000 - fp: 254.0000 - tn: 4962.0000 - fn: 258.0000 - accuracy: 0.9509 - precision: 0.9513 - recall: 0.9505 - auc: 0.9901 - val_loss: 0.3525 - val_tp: 247.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 57.0000 - val_accuracy: 0.8438 - val_precision: 0.8667 - val_recall: 0.8125 - val_auc: 0.9121
# Epoch 10/20
# 163/163 [==============================] - 10s 62ms/step - loss: 0.1420 - tp: 4897.0000 - fp: 273.0000 - tn: 4897.0000 - fn: 273.0000 - accuracy: 0.9472 - precision: 0.9472 - recall: 0.9472 - auc: 0.9879 - val_loss: 0.2136 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9688
# Epoch 11/20
# 163/163 [==============================] - 10s 62ms/step - loss: 0.1215 - tp: 4992.0000 - fp: 222.0000 - tn: 4994.0000 - fn: 224.0000 - accuracy: 0.9572 - precision: 0.9574 - recall: 0.9571 - auc: 0.9903 - val_loss: 0.3176 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9258
# Epoch 12/20
# 163/163 [==============================] - 10s 62ms/step - loss: 0.1178 - tp: 4929.0000 - fp: 228.0000 - tn: 4942.0000 - fn: 241.0000 - accuracy: 0.9546 - precision: 0.9558 - recall: 0.9534 - auc: 0.9907 - val_loss: 0.2582 - val_tp: 285.0000 - val_fp: 19.0000 - val_tn: 285.0000 - val_fn: 19.0000 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9883
# Epoch 13/20
# 163/163 [==============================] - 10s 63ms/step - loss: 0.1205 - tp: 4962.0000 - fp: 227.0000 - tn: 4966.0000 - fn: 231.0000 - accuracy: 0.9559 - precision: 0.9563 - recall: 0.9555 - auc: 0.9906 - val_loss: 0.3023 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9453
# Epoch 14/20
# 163/163 [==============================] - 10s 61ms/step - loss: 0.1169 - tp: 4970.0000 - fp: 226.0000 - tn: 4967.0000 - fn: 223.0000 - accuracy: 0.9568 - precision: 0.9565 - recall: 0.9571 - auc: 0.9912 - val_loss: 0.2507 - val_tp: 285.0000 - val_fp: 19.0000 - val_tn: 285.0000 - val_fn: 19.0000 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9648
# Epoch 15/20
# 163/163 [==============================] - 10s 63ms/step - loss: 0.1105 - tp: 4986.0000 - fp: 212.0000 - tn: 4981.0000 - fn: 207.0000 - accuracy: 0.9597 - precision: 0.9592 - recall: 0.9601 - auc: 0.9918 - val_loss: 0.3373 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9258
# Epoch 16/20
# 163/163 [==============================] - 10s 63ms/step - loss: 0.1107 - tp: 4975.0000 - fp: 218.0000 - tn: 4975.0000 - fn: 218.0000 - accuracy: 0.9580 - precision: 0.9580 - recall: 0.9580 - auc: 0.9923 - val_loss: 1.1136 - val_tp: 190.0000 - val_fp: 114.0000 - val_tn: 190.0000 - val_fn: 114.0000 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.7812
# Epoch 17/20
# 163/163 [==============================] - 10s 62ms/step - loss: 0.1050 - tp: 4987.0000 - fp: 209.0000 - tn: 4984.0000 - fn: 206.0000 - accuracy: 0.9600 - precision: 0.9598 - recall: 0.9603 - auc: 0.9929 - val_loss: 0.2403 - val_tp: 266.0000 - val_fp: 19.0000 - val_tn: 285.0000 - val_fn: 38.0000 - val_accuracy: 0.9062 - val_precision: 0.9333 - val_recall: 0.8750 - val_auc: 0.9727
# Epoch 18/20
# 163/163 [==============================] - 10s 61ms/step - loss: 0.0960 - tp: 4992.0000 - fp: 178.0000 - tn: 4992.0000 - fn: 178.0000 - accuracy: 0.9656 - precision: 0.9656 - recall: 0.9656 - auc: 0.9938 - val_loss: 0.4947 - val_tp: 228.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 76.0000 - val_accuracy: 0.7812 - val_precision: 0.8000 - val_recall: 0.7500 - val_auc: 0.8828
# Epoch 19/20
# 163/163 [==============================] - 10s 62ms/step - loss: 0.0967 - tp: 5034.0000 - fp: 179.0000 - tn: 5037.0000 - fn: 182.0000 - accuracy: 0.9654 - precision: 0.9657 - recall: 0.9651 - auc: 0.9938 - val_loss: 0.6836 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8320
# Epoch 20/20
# 163/163 [==============================] - 10s 61ms/step - loss: 0.0995 - tp: 4995.0000 - fp: 194.0000 - tn: 4999.0000 - fn: 198.0000 - accuracy: 0.9623 - precision: 0.9626 - recall: 0.9619 - auc: 0.9929 - val_loss: 0.3313 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9258

# %%
cnn.plot_history()

# %%
cnn.get_classification_report(test_set)
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.89      0.63      0.74       234
#    PNEUMONIA       0.81      0.95      0.88       390
#
#     accuracy                           0.83       624
#    macro avg       0.85      0.79      0.81       624
# weighted avg       0.84      0.83      0.82       624

# %%
cnn.display_confusion_matrix(test_set)
