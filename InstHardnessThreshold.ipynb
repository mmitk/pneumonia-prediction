# %%
import numpy as np 
import matplotlib.pyplot as plt 
import os
from PIL import Image
print(os.listdir("./common/data"))

import tensorflow as tf

with tf.device('/gpu:1'):
    config = tf.compat.v1.ConfigProto()
    config.gpu_options.allow_growth = True
    tf.compat.v1.keras.backend.set_session(tf.compat.v1.Session(config=config))

# Keras Libraries
import keras
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator, load_img
from sklearn.metrics import classification_report, confusion_matrix
# %matplotlib inline
# Out:
# ['chest_xray', 'resampled', 'TEST']
# Using TensorFlow backend.

# %% [markdown]
# # Resample Data Into New Dataset

# %% [markdown]
# # Resample Train Data

# %%
from common.src import resample as res

# %%
from imblearn.under_sampling import InstanceHardnessThreshold

path = r'C:\Users\mmitk\dev\2020\pneumonia\common\data\chest_xray\train'
IHT = InstanceHardnessThreshold()

# %%
res.resample_directory(IHT, path, 'InstanceHardnessThreshold', val = False)

# %% [markdown]
# # Load Data

# %%
train_folder= './common/data/resampled/InstanceHardnessThreshold/train'
val_folder = './common/data/chest_xray/val/'
test_folder = './common/data/chest_xray/test/'

# %%
# train 
os.listdir(train_folder)
train_n = train_folder+'NORMAL/'
train_p = train_folder+'PNEUMONIA/'

# %%
# test
os.listdir(test_folder)
train_n = test_folder+'NORMAL/'
train_p = test_folder+'PNEUMONIA/'

# %%
from common.src import util

train_datagen = util.create_train_datagen()
test_datagen = util.create_test_datagen()

training_set = util.create_generator_set(train_datagen, './common/data/resampled/InstanceHardnessThreshold/train')
validation_generator = util.create_generator_set(test_datagen, './common/data/chest_xray/val/')
test_set = util.create_generator_set(test_datagen, './common/data/chest_xray/test/', batch_size = 1, shuffle = False)
# Out:
# Found 2972 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %% [markdown]
# # Create Model

# %%
from common.src import models

cnn = models.CNNModel(patience_s = 19)
cnn.create_model()
cnn.summary()

# %% [markdown]
# # Fit Model

# %%
cnn_model = cnn.fit_generator(training_set, validation_generator, epochs=20)
# Out:
# Epoch 1/20
# 163/163 [==============================] - 11s 68ms/step - loss: 0.2882 - tp: 4524.0000 - fp: 692.0000 - tn: 4516.0000 - fn: 684.0000 - accuracy: 0.8679 - precision: 0.8673 - recall: 0.8687 - auc: 0.9517 - val_loss: 0.7694 - val_tp: 190.0000 - val_fp: 114.0000 - val_tn: 190.0000 - val_fn: 114.0000 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.7793
# Epoch 2/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.0916 - tp: 5042.0000 - fp: 165.0000 - tn: 5043.0000 - fn: 166.0000 - accuracy: 0.9682 - precision: 0.9683 - recall: 0.9681 - auc: 0.9946 - val_loss: 0.6944 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8223
# Epoch 3/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.0771 - tp: 5067.0000 - fp: 147.0000 - tn: 5065.0000 - fn: 145.0000 - accuracy: 0.9720 - precision: 0.9718 - recall: 0.9722 - auc: 0.9959 - val_loss: 0.4124 - val_tp: 266.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 38.0000 - val_accuracy: 0.8438 - val_precision: 0.8235 - val_recall: 0.8750 - val_auc: 0.9238
# Epoch 4/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.0686 - tp: 5086.0000 - fp: 120.0000 - tn: 5088.0000 - fn: 122.0000 - accuracy: 0.9768 - precision: 0.9769 - recall: 0.9766 - auc: 0.9966 - val_loss: 1.0479 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.7773
# Epoch 5/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.0777 - tp: 5055.0000 - fp: 153.0000 - tn: 5055.0000 - fn: 153.0000 - accuracy: 0.9706 - precision: 0.9706 - recall: 0.9706 - auc: 0.9958 - val_loss: 0.4437 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.9121
# Epoch 6/20
# 163/163 [==============================] - 10s 58ms/step - loss: 0.0574 - tp: 5102.0000 - fp: 108.0000 - tn: 5104.0000 - fn: 110.0000 - accuracy: 0.9791 - precision: 0.9793 - recall: 0.9789 - auc: 0.9973 - val_loss: 0.4099 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.9375
# Epoch 7/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.0573 - tp: 5091.0000 - fp: 115.0000 - tn: 5093.0000 - fn: 117.0000 - accuracy: 0.9777 - precision: 0.9779 - recall: 0.9775 - auc: 0.9977 - val_loss: 0.2915 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9492
# Epoch 8/20
# 163/163 [==============================] - 10s 58ms/step - loss: 0.0508 - tp: 5105.0000 - fp: 103.0000 - tn: 5105.0000 - fn: 103.0000 - accuracy: 0.9802 - precision: 0.9802 - recall: 0.9802 - auc: 0.9980 - val_loss: 0.3187 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9375
# Epoch 9/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.0439 - tp: 5121.0000 - fp: 89.0000 - tn: 5119.0000 - fn: 87.0000 - accuracy: 0.9831 - precision: 0.9829 - recall: 0.9833 - auc: 0.9984 - val_loss: 0.9211 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8066
# Epoch 10/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.0488 - tp: 5121.0000 - fp: 90.0000 - tn: 5118.0000 - fn: 87.0000 - accuracy: 0.9830 - precision: 0.9827 - recall: 0.9833 - auc: 0.9983 - val_loss: 0.5493 - val_tp: 247.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 57.0000 - val_accuracy: 0.7812 - val_precision: 0.7647 - val_recall: 0.8125 - val_auc: 0.9004
# Epoch 11/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.0489 - tp: 5126.0000 - fp: 84.0000 - tn: 5128.0000 - fn: 86.0000 - accuracy: 0.9837 - precision: 0.9839 - recall: 0.9835 - auc: 0.9980 - val_loss: 0.9041 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8340
# Epoch 12/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.0347 - tp: 5135.0000 - fp: 70.0000 - tn: 5134.0000 - fn: 69.0000 - accuracy: 0.9866 - precision: 0.9866 - recall: 0.9867 - auc: 0.9991 - val_loss: 1.1481 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8203
# Epoch 13/20
# 163/163 [==============================] - 10s 58ms/step - loss: 0.0429 - tp: 5130.0000 - fp: 81.0000 - tn: 5131.0000 - fn: 82.0000 - accuracy: 0.9844 - precision: 0.9845 - recall: 0.9843 - auc: 0.9987 - val_loss: 0.7071 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8828
# Epoch 14/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.0423 - tp: 5138.0000 - fp: 74.0000 - tn: 5138.0000 - fn: 74.0000 - accuracy: 0.9858 - precision: 0.9858 - recall: 0.9858 - auc: 0.9985 - val_loss: 0.5430 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9336
# Epoch 15/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.0356 - tp: 5134.0000 - fp: 74.0000 - tn: 5134.0000 - fn: 74.0000 - accuracy: 0.9858 - precision: 0.9858 - recall: 0.9858 - auc: 0.9992 - val_loss: 0.2050 - val_tp: 285.0000 - val_fp: 19.0000 - val_tn: 285.0000 - val_fn: 19.0000 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9766
# Epoch 16/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.0309 - tp: 5156.0000 - fp: 53.0000 - tn: 5155.0000 - fn: 52.0000 - accuracy: 0.9899 - precision: 0.9898 - recall: 0.9900 - auc: 0.9990 - val_loss: 0.5951 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8945
# Epoch 17/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.0283 - tp: 5154.0000 - fp: 54.0000 - tn: 5154.0000 - fn: 54.0000 - accuracy: 0.9896 - precision: 0.9896 - recall: 0.9896 - auc: 0.9992 - val_loss: 0.3193 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9453
# Epoch 18/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.0283 - tp: 5161.0000 - fp: 51.0000 - tn: 5161.0000 - fn: 51.0000 - accuracy: 0.9902 - precision: 0.9902 - recall: 0.9902 - auc: 0.9994 - val_loss: 1.6563 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.7539
# Epoch 19/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.0360 - tp: 5133.0000 - fp: 71.0000 - tn: 5133.0000 - fn: 71.0000 - accuracy: 0.9864 - precision: 0.9864 - recall: 0.9864 - auc: 0.9991 - val_loss: 0.7370 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8809
# Epoch 20/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.0306 - tp: 5157.0000 - fp: 56.0000 - tn: 5156.0000 - fn: 55.0000 - accuracy: 0.9894 - precision: 0.9893 - recall: 0.9894 - auc: 0.9992 - val_loss: 0.8983 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8320

# %%
cnn.plot_history()

# %%
cnn.get_classification_report(test_set)
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.57      0.97      0.72       234
#    PNEUMONIA       0.97      0.56      0.71       390
#
#     accuracy                           0.71       624
#    macro avg       0.77      0.77      0.71       624
# weighted avg       0.82      0.71      0.71       624

# %%
cnn.display_confusion_matrix(test_set)
