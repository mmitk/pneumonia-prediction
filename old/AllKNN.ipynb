# %%
import numpy as np 
import matplotlib.pyplot as plt 
import os
from PIL import Image
print(os.listdir("./common/data"))

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
tf.compat.v1.keras.backend.set_session(tf.compat.v1.Session(config=config))

# Keras Libraries
import keras
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator, load_img
from sklearn.metrics import classification_report, confusion_matrix
# %matplotlib inline
# Out:
# ['chest_xray', 'resampled', 'TEST']
# Using TensorFlow backend.

# %% [markdown]
# # Resample Data Into New Dataset

# %% [markdown]
# # Resample Train Data

# %%
from common.src import resample as res

# %%
from imblearn.under_sampling import AllKNN

path = r'C:\Users\mmitk\dev\2020\pneumonia\common\data\chest_xray\train'
All = AllKNN()

# %%
res.resample_directory(All, path, 'AllKNN', val = False)

# %% [markdown]
# # Load Data

# %%
train_folder= './common/data/resampled/AllKNN/train'
val_folder = './common/data/chest_xray/val/'
test_folder = './common/data/chest_xray/test/'

# %%
# train 
os.listdir(train_folder)
train_n = train_folder+'NORMAL/'
train_p = train_folder+'PNEUMONIA/'

# %%
# test
os.listdir(test_folder)
train_n = test_folder+'NORMAL/'
train_p = test_folder+'PNEUMONIA/'

# %%
from common.src import util

train_datagen = util.create_train_datagen()
test_datagen = util.create_test_datagen()

training_set = util.create_generator_set(train_datagen, './common/data/resampled/AllKNN/train')
validation_generator = util.create_generator_set(test_datagen, './common/data/chest_xray/val/')
test_set = util.create_generator_set(test_datagen, './common/data/chest_xray/test/', batch_size = 1, shuffle = False)
# Out:
# Found 4944 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %% [markdown]
# # Create Model

# %%
from common.src import models

cnn = models.CNNModel(patience_s = 19)
cnn.create_model()
cnn.summary()

# %% [markdown]
# # Fit Model

# %%
cnn_model = cnn.fit_generator(training_set, validation_generator, epochs=20)
# Out:
# Epoch 1/20
# 163/163 [==============================] - 11s 67ms/step - loss: 0.3551 - tp: 4399.0000 - fp: 771.0000 - tn: 4429.0000 - fn: 801.0000 - accuracy: 0.8488 - precision: 0.8509 - recall: 0.8460 - auc: 0.9225 - val_loss: 0.3007 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9453
# Epoch 2/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.2111 - tp: 4755.0000 - fp: 455.0000 - tn: 4745.0000 - fn: 445.0000 - accuracy: 0.9135 - precision: 0.9127 - recall: 0.9144 - auc: 0.9727 - val_loss: 0.2273 - val_tp: 285.0000 - val_fp: 19.0000 - val_tn: 285.0000 - val_fn: 19.0000 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9766
# Epoch 3/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.1920 - tp: 4763.0000 - fp: 422.0000 - tn: 4762.0000 - fn: 421.0000 - accuracy: 0.9187 - precision: 0.9186 - recall: 0.9188 - auc: 0.9777 - val_loss: 0.5770 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8477
# Epoch 4/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.1920 - tp: 4819.0000 - fp: 404.0000 - tn: 4812.0000 - fn: 397.0000 - accuracy: 0.9232 - precision: 0.9226 - recall: 0.9239 - auc: 0.9770 - val_loss: 0.3061 - val_tp: 285.0000 - val_fp: 19.0000 - val_tn: 285.0000 - val_fn: 19.0000 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9414
# Epoch 5/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.1625 - tp: 4868.0000 - fp: 315.0000 - tn: 4869.0000 - fn: 316.0000 - accuracy: 0.9391 - precision: 0.9392 - recall: 0.9390 - auc: 0.9833 - val_loss: 0.4125 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8867
# Epoch 6/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.1538 - tp: 4888.0000 - fp: 306.0000 - tn: 4894.0000 - fn: 312.0000 - accuracy: 0.9406 - precision: 0.9411 - recall: 0.9400 - auc: 0.9852 - val_loss: 0.3779 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9121
# Epoch 7/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.1433 - tp: 4919.0000 - fp: 306.0000 - tn: 4910.0000 - fn: 297.0000 - accuracy: 0.9422 - precision: 0.9414 - recall: 0.9431 - auc: 0.9874 - val_loss: 0.2719 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9531
# Epoch 8/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.1359 - tp: 4932.0000 - fp: 266.0000 - tn: 4934.0000 - fn: 268.0000 - accuracy: 0.9487 - precision: 0.9488 - recall: 0.9485 - auc: 0.9882 - val_loss: 0.3974 - val_tp: 209.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 95.0000 - val_accuracy: 0.7812 - val_precision: 0.8462 - val_recall: 0.6875 - val_auc: 0.8945
# Epoch 9/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.1275 - tp: 4948.0000 - fp: 265.0000 - tn: 4935.0000 - fn: 252.0000 - accuracy: 0.9503 - precision: 0.9492 - recall: 0.9515 - auc: 0.9895 - val_loss: 0.2950 - val_tp: 247.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 57.0000 - val_accuracy: 0.7812 - val_precision: 0.7647 - val_recall: 0.8125 - val_auc: 0.9336
# Epoch 10/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.1121 - tp: 4979.0000 - fp: 223.0000 - tn: 4977.0000 - fn: 221.0000 - accuracy: 0.9573 - precision: 0.9571 - recall: 0.9575 - auc: 0.9916 - val_loss: 0.3587 - val_tp: 228.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 76.0000 - val_accuracy: 0.7812 - val_precision: 0.8000 - val_recall: 0.7500 - val_auc: 0.9141
# Epoch 11/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.1033 - tp: 4996.0000 - fp: 185.0000 - tn: 4999.0000 - fn: 188.0000 - accuracy: 0.9640 - precision: 0.9643 - recall: 0.9637 - auc: 0.9926 - val_loss: 0.3923 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.9375
# Epoch 12/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.1151 - tp: 4984.0000 - fp: 212.0000 - tn: 4988.0000 - fn: 216.0000 - accuracy: 0.9588 - precision: 0.9592 - recall: 0.9585 - auc: 0.9911 - val_loss: 0.5270 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8672
# Epoch 13/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.1033 - tp: 5007.0000 - fp: 190.0000 - tn: 5010.0000 - fn: 193.0000 - accuracy: 0.9632 - precision: 0.9634 - recall: 0.9629 - auc: 0.9933 - val_loss: 0.2274 - val_tp: 285.0000 - val_fp: 19.0000 - val_tn: 285.0000 - val_fn: 19.0000 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9922
# Epoch 14/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.1045 - tp: 5007.0000 - fp: 199.0000 - tn: 5017.0000 - fn: 209.0000 - accuracy: 0.9609 - precision: 0.9618 - recall: 0.9599 - auc: 0.9929 - val_loss: 0.2553 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9805
# Epoch 15/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.1019 - tp: 4993.0000 - fp: 191.0000 - tn: 4993.0000 - fn: 191.0000 - accuracy: 0.9632 - precision: 0.9632 - recall: 0.9632 - auc: 0.9931 - val_loss: 0.2218 - val_tp: 266.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 38.0000 - val_accuracy: 0.8438 - val_precision: 0.8235 - val_recall: 0.8750 - val_auc: 0.9648
# Epoch 16/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.0985 - tp: 5004.0000 - fp: 187.0000 - tn: 5013.0000 - fn: 196.0000 - accuracy: 0.9632 - precision: 0.9640 - recall: 0.9623 - auc: 0.9933 - val_loss: 0.6956 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.7969
# Epoch 17/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.0904 - tp: 5029.0000 - fp: 172.0000 - tn: 5028.0000 - fn: 171.0000 - accuracy: 0.9670 - precision: 0.9669 - recall: 0.9671 - auc: 0.9946 - val_loss: 0.4260 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8711
# Epoch 18/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.0913 - tp: 5016.0000 - fp: 182.0000 - tn: 5018.0000 - fn: 184.0000 - accuracy: 0.9648 - precision: 0.9650 - recall: 0.9646 - auc: 0.9946 - val_loss: 0.5648 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8359
# Epoch 19/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.0741 - tp: 5057.0000 - fp: 141.0000 - tn: 5059.0000 - fn: 143.0000 - accuracy: 0.9727 - precision: 0.9729 - recall: 0.9725 - auc: 0.9963 - val_loss: 0.7026 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8262
# Epoch 20/20
# 163/163 [==============================] - 10s 61ms/step - loss: 0.0833 - tp: 5035.0000 - fp: 162.0000 - tn: 5038.0000 - fn: 165.0000 - accuracy: 0.9686 - precision: 0.9688 - recall: 0.9683 - auc: 0.9953 - val_loss: 0.3716 - val_tp: 247.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 57.0000 - val_accuracy: 0.7812 - val_precision: 0.7647 - val_recall: 0.8125 - val_auc: 0.8984

# %%
cnn.plot_history()

# %%
cnn.get_classification_report(test_set)
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.81      0.85      0.83       234
#    PNEUMONIA       0.91      0.88      0.89       390
#
#     accuracy                           0.87       624
#    macro avg       0.86      0.87      0.86       624
# weighted avg       0.87      0.87      0.87       624

# %%
cnn.display_confusion_matrix(test_set)
