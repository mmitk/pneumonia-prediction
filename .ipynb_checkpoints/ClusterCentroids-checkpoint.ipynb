# %%
import numpy as np 
import matplotlib.pyplot as plt 
import os
from PIL import Image
print(os.listdir("./common/data"))

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
tf.compat.v1.keras.backend.set_session(tf.compat.v1.Session(config=config))

# Keras Libraries
import keras
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator, load_img
from sklearn.metrics import classification_report, confusion_matrix
# %matplotlib inline
# Out:
# ['chest_xray', 'resampled', 'TEST']
# Using TensorFlow backend.

# %% [markdown]
# # Resample Data Into New Dataset

# %% [markdown]
# # Resample Train Data

# %%
from common.src import resample as res

# %%
from imblearn.under_sampling import ClusterCentroids

path = r'C:\Users\mmitk\dev\2020\pneumonia\common\data\chest_xray\train'
cc = ClusterCentroids()

# %%
res.resample_directory(cc, path, 'ClustCent', val = False)

# %% [markdown]
# # Load Data

# %%
train_folder= './common/data/resampled/ClustCent/train'
val_folder = './common/data/chest_xray/val/'
test_folder = './common/data/chest_xray/test/'

# %%
# train 
os.listdir(train_folder)
train_n = train_folder+'NORMAL/'
train_p = train_folder+'PNEUMONIA/'

# %%
from common.src import util

train_datagen = util.create_train_datagen()
test_datagen = util.create_test_datagen()

training_set = util.create_generator_set(train_datagen, './common/data/resampled/ClustCent/train')
validation_generator = util.create_generator_set(test_datagen, './common/data/chest_xray/val/')
test_set = util.create_generator_set(test_datagen, './common/data/chest_xray/test/')
# Out:
# Found 2682 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %% [markdown]
# # Create Model

# %%
from common.src import models

cnn20 = models.CNNModel(patience_s=19)
cnn20.create_model()
cnn20.summary()

# %% [markdown]
# # Fit Model

# %%
cnn_model = cnn20.fit_generator(training_set, validation_generator, epochs=20)
# Out:
# Epoch 1/20
# 163/163 [==============================] - 12s 72ms/step - loss: 0.4193 - tp: 4103.0000 - fp: 1045.0000 - tn: 4159.0000 - fn: 1101.0000 - accuracy: 0.7938 - precision: 0.7970 - recall: 0.7884 - auc: 0.8885 - val_loss: 0.3018 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9805
# Epoch 2/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.2768 - tp: 4619.0000 - fp: 578.0000 - tn: 4626.0000 - fn: 585.0000 - accuracy: 0.8883 - precision: 0.8888 - recall: 0.8876 - auc: 0.9535 - val_loss: 0.4828 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8555
# Epoch 3/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.2347 - tp: 4704.0000 - fp: 488.0000 - tn: 4716.0000 - fn: 500.0000 - accuracy: 0.9051 - precision: 0.9060 - recall: 0.9039 - auc: 0.9663 - val_loss: 0.4394 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8633
# Epoch 4/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.2194 - tp: 4748.0000 - fp: 444.0000 - tn: 4760.0000 - fn: 456.0000 - accuracy: 0.9135 - precision: 0.9145 - recall: 0.9124 - auc: 0.9701 - val_loss: 0.5906 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8477
# Epoch 5/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.1964 - tp: 4814.0000 - fp: 388.0000 - tn: 4816.0000 - fn: 390.0000 - accuracy: 0.9252 - precision: 0.9254 - recall: 0.9251 - auc: 0.9760 - val_loss: 0.4625 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8594
# Epoch 6/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.2023 - tp: 4784.0000 - fp: 422.0000 - tn: 4788.0000 - fn: 426.0000 - accuracy: 0.9186 - precision: 0.9189 - recall: 0.9182 - auc: 0.9751 - val_loss: 0.3703 - val_tp: 228.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 76.0000 - val_accuracy: 0.7812 - val_precision: 0.8000 - val_recall: 0.7500 - val_auc: 0.9238
# Epoch 7/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.1841 - tp: 4838.0000 - fp: 358.0000 - tn: 4840.0000 - fn: 360.0000 - accuracy: 0.9309 - precision: 0.9311 - recall: 0.9307 - auc: 0.9786 - val_loss: 0.3640 - val_tp: 228.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 76.0000 - val_accuracy: 0.7812 - val_precision: 0.8000 - val_recall: 0.7500 - val_auc: 0.9180
# Epoch 8/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.1665 - tp: 4880.0000 - fp: 325.0000 - tn: 4885.0000 - fn: 330.0000 - accuracy: 0.9371 - precision: 0.9376 - recall: 0.9367 - auc: 0.9824 - val_loss: 0.4951 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8652
# Epoch 9/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.1616 - tp: 4878.0000 - fp: 318.0000 - tn: 4880.0000 - fn: 320.0000 - accuracy: 0.9386 - precision: 0.9388 - recall: 0.9384 - auc: 0.9835 - val_loss: 0.4247 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8809
# Epoch 10/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.1500 - tp: 4903.0000 - fp: 314.0000 - tn: 4896.0000 - fn: 307.0000 - accuracy: 0.9404 - precision: 0.9398 - recall: 0.9411 - auc: 0.9856 - val_loss: 0.3384 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9336
# Epoch 11/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.1572 - tp: 4888.0000 - fp: 303.0000 - tn: 4895.0000 - fn: 310.0000 - accuracy: 0.9410 - precision: 0.9416 - recall: 0.9404 - auc: 0.9843 - val_loss: 0.3410 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9258
# Epoch 12/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.1317 - tp: 4953.0000 - fp: 253.0000 - tn: 4957.0000 - fn: 257.0000 - accuracy: 0.9511 - precision: 0.9514 - recall: 0.9507 - auc: 0.9888 - val_loss: 0.3862 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8809
# Epoch 13/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.1438 - tp: 4918.0000 - fp: 293.0000 - tn: 4911.0000 - fn: 286.0000 - accuracy: 0.9444 - precision: 0.9438 - recall: 0.9450 - auc: 0.9868 - val_loss: 0.3239 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9336
# Epoch 14/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.1369 - tp: 4928.0000 - fp: 265.0000 - tn: 4939.0000 - fn: 276.0000 - accuracy: 0.9480 - precision: 0.9490 - recall: 0.9470 - auc: 0.9881 - val_loss: 0.3779 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9102
# Epoch 15/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.1218 - tp: 4968.0000 - fp: 238.0000 - tn: 4966.0000 - fn: 236.0000 - accuracy: 0.9545 - precision: 0.9543 - recall: 0.9547 - auc: 0.9908 - val_loss: 0.4823 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8711
# Epoch 16/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.1285 - tp: 4946.0000 - fp: 258.0000 - tn: 4946.0000 - fn: 258.0000 - accuracy: 0.9504 - precision: 0.9504 - recall: 0.9504 - auc: 0.9893 - val_loss: 0.4366 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8789
# Epoch 17/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.1210 - tp: 4966.0000 - fp: 241.0000 - tn: 4963.0000 - fn: 238.0000 - accuracy: 0.9540 - precision: 0.9537 - recall: 0.9543 - auc: 0.9907 - val_loss: 0.3893 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9180
# Epoch 18/20
# 163/163 [==============================] - 10s 61ms/step - loss: 0.1280 - tp: 4955.0000 - fp: 239.0000 - tn: 4965.0000 - fn: 249.0000 - accuracy: 0.9531 - precision: 0.9540 - recall: 0.9522 - auc: 0.9893 - val_loss: 0.3744 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9023
# Epoch 19/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.1078 - tp: 4977.0000 - fp: 232.0000 - tn: 4972.0000 - fn: 227.0000 - accuracy: 0.9559 - precision: 0.9555 - recall: 0.9564 - auc: 0.9929 - val_loss: 0.3436 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9219
# Epoch 20/20
# 163/163 [==============================] - 9s 58ms/step - loss: 0.1161 - tp: 4987.0000 - fp: 217.0000 - tn: 4987.0000 - fn: 217.0000 - accuracy: 0.9583 - precision: 0.9583 - recall: 0.9583 - auc: 0.9911 - val_loss: 0.3758 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9082

# %%
cnn20.plot_history()

# %%
cnn20.get_classification_report(test_set)
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.40      0.30      0.34       234
#    PNEUMONIA       0.64      0.73      0.68       390
#
#     accuracy                           0.57       624
#    macro avg       0.52      0.52      0.51       624
# weighted avg       0.55      0.57      0.55       624

# %%
cnn20.display_confusion_matrix(test_set)
