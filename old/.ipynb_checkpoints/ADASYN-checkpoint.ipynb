# %%
import numpy as np 
import matplotlib.pyplot as plt 
import os
from PIL import Image
print(os.listdir("./common/data"))

import tensorflow as tf

config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
tf.compat.v1.keras.backend.set_session(tf.compat.v1.Session(config=config))

# Keras Libraries
import keras
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator, load_img
from sklearn.metrics import classification_report, confusion_matrix
# %matplotlib inline
# Out:
# ['chest_xray', 'resampled', 'TEST']
# Using TensorFlow backend.

# %% [markdown]
# # Resample Data Into New Dataset

# %% [markdown]
# # Resample Train Data

# %%
from common.src import resample as res

# %%
from imblearn.over_sampling import ADASYN

path = r'C:\Users\mmitk\dev\2020\pneumonia\common\data\chest_xray\train'
ads = ADASYN(random_state=0)

# %%
res.resample_directory(ads, path, 'ADASYN', val = False)

# %% [markdown]
# # Load Data

# %%
train_folder= './common/data/resampled/ADASYN/train'
val_folder = './common/data/chest_xray/val/'
test_folder = './common/data/chest_xray/test/'

# %%
# train 
os.listdir(train_folder)
train_n = train_folder+'NORMAL/'
train_p = train_folder+'PNEUMONIA/'

# %%
# test
os.listdir(test_folder)
train_n = test_folder+'NORMAL/'
train_p = test_folder+'PNEUMONIA/'

# %%
from common.src import util

train_datagen = util.create_train_datagen()
test_datagen = util.create_test_datagen()

training_set = util.create_generator_set(train_datagen, './common/data/resampled/ADASYN/train')
validation_generator = util.create_generator_set(test_datagen, './common/data/chest_xray/val/')
test_set = util.create_generator_set(test_datagen, './common/data/chest_xray/test/', batch_size = 1, shuffle = False)
# Out:
# Found 7666 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %% [markdown]
# # Create Model

# %%
from common.src import models

cnn = models.CNNModel(patience_s=19)
cnn.create_model()
cnn.summary()

# %% [markdown]
# # Fit Model

# %%
cnn_model = cnn.fit_generator(training_set, validation_generator, epochs=20)
# Out:
# Epoch 1/20
# 163/163 [==============================] - 11s 69ms/step - loss: 0.3431 - tp: 4275.0000 - fp: 872.0000 - tn: 4330.0000 - fn: 927.0000 - accuracy: 0.8271 - precision: 0.8306 - recall: 0.8218 - auc: 0.9254 - val_loss: 0.5916 - val_tp: 209.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 95.0000 - val_accuracy: 0.7188 - val_precision: 0.7333 - val_recall: 0.6875 - val_auc: 0.8340
# Epoch 2/20
# 163/163 [==============================] - 10s 60ms/step - loss: 0.2055 - tp: 4792.0000 - fp: 427.0000 - tn: 4789.0000 - fn: 424.0000 - accuracy: 0.9184 - precision: 0.9182 - recall: 0.9187 - auc: 0.9741 - val_loss: 0.6176 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8164
# Epoch 3/20
# 163/163 [==============================] - 10s 60ms/step - loss: 0.1966 - tp: 4792.0000 - fp: 413.0000 - tn: 4789.0000 - fn: 410.0000 - accuracy: 0.9209 - precision: 0.9207 - recall: 0.9212 - auc: 0.9764 - val_loss: 0.5495 - val_tp: 209.0000 - val_fp: 114.0000 - val_tn: 190.0000 - val_fn: 95.0000 - val_accuracy: 0.6562 - val_precision: 0.6471 - val_recall: 0.6875 - val_auc: 0.8086
# Epoch 4/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.1963 - tp: 4779.0000 - fp: 422.0000 - tn: 4780.0000 - fn: 423.0000 - accuracy: 0.9188 - precision: 0.9189 - recall: 0.9187 - auc: 0.9764 - val_loss: 0.6251 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8164
# Epoch 5/20
# 163/163 [==============================] - 10s 60ms/step - loss: 0.1729 - tp: 4852.0000 - fp: 366.0000 - tn: 4850.0000 - fn: 364.0000 - accuracy: 0.9300 - precision: 0.9299 - recall: 0.9302 - auc: 0.9816 - val_loss: 0.4894 - val_tp: 209.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 95.0000 - val_accuracy: 0.7500 - val_precision: 0.7857 - val_recall: 0.6875 - val_auc: 0.8438
# Epoch 6/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.1461 - tp: 4896.0000 - fp: 303.0000 - tn: 4899.0000 - fn: 306.0000 - accuracy: 0.9415 - precision: 0.9417 - recall: 0.9412 - auc: 0.9868 - val_loss: 0.3447 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9336
# Epoch 7/20
# 163/163 [==============================] - 10s 60ms/step - loss: 0.1532 - tp: 4885.0000 - fp: 329.0000 - tn: 4887.0000 - fn: 331.0000 - accuracy: 0.9367 - precision: 0.9369 - recall: 0.9365 - auc: 0.9856 - val_loss: 0.3916 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.9023
# Epoch 8/20
# 163/163 [==============================] - 10s 60ms/step - loss: 0.1469 - tp: 4897.0000 - fp: 306.0000 - tn: 4896.0000 - fn: 305.0000 - accuracy: 0.9413 - precision: 0.9412 - recall: 0.9414 - auc: 0.9868 - val_loss: 0.4067 - val_tp: 209.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 95.0000 - val_accuracy: 0.7500 - val_precision: 0.7857 - val_recall: 0.6875 - val_auc: 0.8867
# Epoch 9/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.1554 - tp: 4877.0000 - fp: 325.0000 - tn: 4877.0000 - fn: 325.0000 - accuracy: 0.9375 - precision: 0.9375 - recall: 0.9375 - auc: 0.9848 - val_loss: 0.3159 - val_tp: 247.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 57.0000 - val_accuracy: 0.8438 - val_precision: 0.8667 - val_recall: 0.8125 - val_auc: 0.9453
# Epoch 10/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.1297 - tp: 4937.0000 - fp: 264.0000 - tn: 4938.0000 - fn: 265.0000 - accuracy: 0.9492 - precision: 0.9492 - recall: 0.9491 - auc: 0.9894 - val_loss: 0.3149 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9453
# Epoch 11/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.1321 - tp: 4913.0000 - fp: 286.0000 - tn: 4916.0000 - fn: 289.0000 - accuracy: 0.9447 - precision: 0.9450 - recall: 0.9444 - auc: 0.9891 - val_loss: 0.4503 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8594
# Epoch 12/20
# 163/163 [==============================] - 10s 60ms/step - loss: 0.1170 - tp: 4980.0000 - fp: 233.0000 - tn: 4983.0000 - fn: 236.0000 - accuracy: 0.9550 - precision: 0.9553 - recall: 0.9548 - auc: 0.9915 - val_loss: 0.2690 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9766
# Epoch 13/20
# 163/163 [==============================] - 10s 61ms/step - loss: 0.1119 - tp: 4976.0000 - fp: 227.0000 - tn: 4975.0000 - fn: 226.0000 - accuracy: 0.9565 - precision: 0.9564 - recall: 0.9566 - auc: 0.9920 - val_loss: 0.2398 - val_tp: 285.0000 - val_fp: 19.0000 - val_tn: 285.0000 - val_fn: 19.0000 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9805
# Epoch 14/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.1155 - tp: 4979.0000 - fp: 241.0000 - tn: 4975.0000 - fn: 237.0000 - accuracy: 0.9542 - precision: 0.9538 - recall: 0.9546 - auc: 0.9916 - val_loss: 0.3504 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9336
# Epoch 15/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.1129 - tp: 4970.0000 - fp: 227.0000 - tn: 4975.0000 - fn: 232.0000 - accuracy: 0.9559 - precision: 0.9563 - recall: 0.9554 - auc: 0.9919 - val_loss: 0.5187 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8457
# Epoch 16/20
# 163/163 [==============================] - 10s 60ms/step - loss: 0.1002 - tp: 5011.0000 - fp: 205.0000 - tn: 5011.0000 - fn: 205.0000 - accuracy: 0.9607 - precision: 0.9607 - recall: 0.9607 - auc: 0.9938 - val_loss: 0.3377 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.9336
# Epoch 17/20
# 163/163 [==============================] - 10s 60ms/step - loss: 0.0999 - tp: 5009.0000 - fp: 192.0000 - tn: 5010.0000 - fn: 193.0000 - accuracy: 0.9630 - precision: 0.9631 - recall: 0.9629 - auc: 0.9931 - val_loss: 0.9500 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.7656
# Epoch 18/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.1144 - tp: 4965.0000 - fp: 235.0000 - tn: 4967.0000 - fn: 237.0000 - accuracy: 0.9546 - precision: 0.9548 - recall: 0.9544 - auc: 0.9920 - val_loss: 0.6354 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8086
# Epoch 19/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.1030 - tp: 5009.0000 - fp: 203.0000 - tn: 5013.0000 - fn: 207.0000 - accuracy: 0.9607 - precision: 0.9611 - recall: 0.9603 - auc: 0.9933 - val_loss: 0.2663 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9590
# Epoch 20/20
# 163/163 [==============================] - 10s 59ms/step - loss: 0.1031 - tp: 4971.0000 - fp: 216.0000 - tn: 4972.0000 - fn: 217.0000 - accuracy: 0.9583 - precision: 0.9584 - recall: 0.9582 - auc: 0.9931 - val_loss: 0.4237 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9023

# %%
cnn.plot_history()

# %%
cnn.get_classification_report(test_set)
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.86      0.60      0.71       234
#    PNEUMONIA       0.80      0.94      0.86       390
#
#     accuracy                           0.81       624
#    macro avg       0.83      0.77      0.79       624
# weighted avg       0.82      0.81      0.81       624

# %%
cnn.display_confusion_matrix(test_set)
