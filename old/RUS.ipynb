# %%
import numpy as np 
import matplotlib.pyplot as plt 
import os
from PIL import Image
print(os.listdir("./common/data"))

import tensorflow as tf


config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
tf.compat.v1.keras.backend.set_session(tf.compat.v1.Session(config=config))

# Keras Libraries
import keras
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator, load_img
from sklearn.metrics import classification_report, confusion_matrix
# %matplotlib inline
# Out:
# ['chest_xray', 'resampled', 'TEST']
# Using TensorFlow backend.

# %% [markdown]
# # Resample Data Into New Dataset

# %% [markdown]
# # Resample Train Data

# %%
from common.src import resample as res

# %%
from imblearn.under_sampling import RandomUnderSampler

path = r'C:\Users\mmitk\dev\2020\pneumonia\common\data\chest_xray\train'
rus = RandomUnderSampler()

# %%
res.resample_directory(rus, path, 'RandomUnderSampler', val = False)
# Out:
# ----------[LOADING IMAGES]----------
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ......................
# Finished [LOADING IMAGES]
# ----------[RESAMPLING IMAGES]----------
#
# Finished [RESAMPLING IMAGES]
# ----------[WRITING RESAMPLED IMAGES]----------
# ....................................................................................................
# ....................................................................................................
# .....................................................................
# Finished [RESAMPLING DIRECTORY]

# %% [markdown]
# # Load Data

# %%
train_folder= './common/data/resampled/RandomUnderSampler/train'
val_folder = './common/data/chest_xray/val/'
test_folder = './common/data/chest_xray/test/'

# %%
# train 
os.listdir(train_folder)
train_n = train_folder+'NORMAL/'
train_p = train_folder+'PNEUMONIA/'

# %%
# test
os.listdir(test_folder)
train_n = test_folder+'NORMAL/'
train_p = test_folder+'PNEUMONIA/'

# %%
from common.src import util

train_datagen = util.create_train_datagen()
test_datagen = util.create_test_datagen()

training_set = util.create_generator_set(train_datagen, './common/data/resampled/RandomUnderSampler/train')
validation_generator = util.create_generator_set(test_datagen, './common/data/chest_xray/val/')
test_set = util.create_generator_set(test_datagen, './common/data/chest_xray/test/', batch_size = 1, shuffle = False)
# Out:
# Found 2682 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %% [markdown]
# # Create Model

# %%
from common.src import models

cnn = models.CNNModel(patience_s = 19)
cnn.create_model()
cnn.summary()

# %% [markdown]
# # Fit Model

# %%
cnn_model = cnn.fit_generator(training_set, validation_generator, epochs=20)
# Out:
# Epoch 1/20
# 163/163 [==============================] - 12s 73ms/step - loss: 0.4073 - tp: 4214.0000 - fp: 1010.0000 - tn: 4194.0000 - fn: 990.0000 - accuracy: 0.8078 - precision: 0.8067 - recall: 0.8098 - auc: 0.8966 - val_loss: 0.3562 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9199
# Epoch 2/20
# 163/163 [==============================] - 11s 65ms/step - loss: 0.2501 - tp: 4650.0000 - fp: 555.0000 - tn: 4649.0000 - fn: 554.0000 - accuracy: 0.8934 - precision: 0.8934 - recall: 0.8935 - auc: 0.9622 - val_loss: 0.3069 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9551
# Epoch 3/20
# 163/163 [==============================] - 10s 63ms/step - loss: 0.2362 - tp: 4709.0000 - fp: 494.0000 - tn: 4710.0000 - fn: 495.0000 - accuracy: 0.9050 - precision: 0.9051 - recall: 0.9049 - auc: 0.9657 - val_loss: 0.2928 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9531
# Epoch 4/20
# 163/163 [==============================] - 10s 63ms/step - loss: 0.2031 - tp: 4791.0000 - fp: 426.0000 - tn: 4784.0000 - fn: 419.0000 - accuracy: 0.9189 - precision: 0.9183 - recall: 0.9196 - auc: 0.9748 - val_loss: 0.3356 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9180
# Epoch 5/20
# 163/163 [==============================] - 10s 63ms/step - loss: 0.1697 - tp: 4853.0000 - fp: 353.0000 - tn: 4851.0000 - fn: 351.0000 - accuracy: 0.9324 - precision: 0.9322 - recall: 0.9326 - auc: 0.9818 - val_loss: 0.3182 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9316
# Epoch 6/20
# 163/163 [==============================] - 10s 64ms/step - loss: 0.1707 - tp: 4849.0000 - fp: 347.0000 - tn: 4857.0000 - fn: 355.0000 - accuracy: 0.9326 - precision: 0.9332 - recall: 0.9318 - auc: 0.9821 - val_loss: 0.4330 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.8750
# Epoch 7/20
# 163/163 [==============================] - 10s 63ms/step - loss: 0.1525 - tp: 4902.0000 - fp: 303.0000 - tn: 4901.0000 - fn: 302.0000 - accuracy: 0.9419 - precision: 0.9418 - recall: 0.9420 - auc: 0.9850 - val_loss: 0.4243 - val_tp: 228.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 76.0000 - val_accuracy: 0.7812 - val_precision: 0.8000 - val_recall: 0.7500 - val_auc: 0.8848
# Epoch 8/20
# 163/163 [==============================] - 10s 64ms/step - loss: 0.1462 - tp: 4902.0000 - fp: 296.0000 - tn: 4902.0000 - fn: 296.0000 - accuracy: 0.9431 - precision: 0.9431 - recall: 0.9431 - auc: 0.9869 - val_loss: 0.5839 - val_tp: 190.0000 - val_fp: 114.0000 - val_tn: 190.0000 - val_fn: 114.0000 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.7969
# Epoch 9/20
# 163/163 [==============================] - 10s 63ms/step - loss: 0.1437 - tp: 4920.0000 - fp: 289.0000 - tn: 4921.0000 - fn: 290.0000 - accuracy: 0.9444 - precision: 0.9445 - recall: 0.9443 - auc: 0.9873 - val_loss: 0.3142 - val_tp: 285.0000 - val_fp: 19.0000 - val_tn: 285.0000 - val_fn: 19.0000 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9453p: 124.0000 - tn: 1860.0000 - fn: 126.0000 - accuracy: 0.93
# Epoch 10/20
# 163/163 [==============================] - 10s 64ms/step - loss: 0.1474 - tp: 4904.0000 - fp: 298.0000 - tn: 4906.0000 - fn: 300.0000 - accuracy: 0.9425 - precision: 0.9427 - recall: 0.9424 - auc: 0.9865 - val_loss: 0.3371 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9297
# Epoch 11/20
# 163/163 [==============================] - 10s 64ms/step - loss: 0.1390 - tp: 4942.0000 - fp: 257.0000 - tn: 4941.0000 - fn: 256.0000 - accuracy: 0.9507 - precision: 0.9506 - recall: 0.9508 - auc: 0.9882 - val_loss: 0.3670 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9062
# Epoch 12/20
# 163/163 [==============================] - 11s 65ms/step - loss: 0.1305 - tp: 4940.0000 - fp: 261.0000 - tn: 4943.0000 - fn: 264.0000 - accuracy: 0.9496 - precision: 0.9498 - recall: 0.9493 - auc: 0.9894 - val_loss: 0.4358 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8828
# Epoch 13/20
# 163/163 [==============================] - 10s 64ms/step - loss: 0.1230 - tp: 4975.0000 - fp: 237.0000 - tn: 4973.0000 - fn: 235.0000 - accuracy: 0.9547 - precision: 0.9545 - recall: 0.9549 - auc: 0.9906 - val_loss: 0.4150 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8906
# Epoch 14/20
# 163/163 [==============================] - 10s 64ms/step - loss: 0.1183 - tp: 4971.0000 - fp: 235.0000 - tn: 4969.0000 - fn: 233.0000 - accuracy: 0.9550 - precision: 0.9549 - recall: 0.9552 - auc: 0.9911 - val_loss: 0.4300 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8672
# Epoch 15/20
# 163/163 [==============================] - 10s 63ms/step - loss: 0.1277 - tp: 4966.0000 - fp: 246.0000 - tn: 4958.0000 - fn: 238.0000 - accuracy: 0.9535 - precision: 0.9528 - recall: 0.9543 - auc: 0.9895 - val_loss: 0.2156 - val_tp: 285.0000 - val_fp: 19.0000 - val_tn: 285.0000 - val_fn: 19.0000 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9766
# Epoch 16/20
# 163/163 [==============================] - 10s 64ms/step - loss: 0.1218 - tp: 4959.0000 - fp: 244.0000 - tn: 4960.0000 - fn: 245.0000 - accuracy: 0.9530 - precision: 0.9531 - recall: 0.9529 - auc: 0.9902 - val_loss: 0.3554 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9277
# Epoch 17/20
# 163/163 [==============================] - 10s 63ms/step - loss: 0.1081 - tp: 4980.0000 - fp: 226.0000 - tn: 4978.0000 - fn: 224.0000 - accuracy: 0.9568 - precision: 0.9566 - recall: 0.9570 - auc: 0.9926 - val_loss: 0.4187 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8789
# Epoch 18/20
# 163/163 [==============================] - 11s 66ms/step - loss: 0.1053 - tp: 4989.0000 - fp: 216.0000 - tn: 4988.0000 - fn: 215.0000 - accuracy: 0.9586 - precision: 0.9585 - recall: 0.9587 - auc: 0.9932 - val_loss: 0.2834 - val_tp: 247.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 57.0000 - val_accuracy: 0.7812 - val_precision: 0.7647 - val_recall: 0.8125 - val_auc: 0.9453
# Epoch 19/20
# 163/163 [==============================] - 10s 64ms/step - loss: 0.1077 - tp: 5000.0000 - fp: 216.0000 - tn: 4994.0000 - fn: 210.0000 - accuracy: 0.9591 - precision: 0.9586 - recall: 0.9597 - auc: 0.9927 - val_loss: 0.3387 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9316
# Epoch 20/20
# 163/163 [==============================] - 10s 63ms/step - loss: 0.0895 - tp: 5037.0000 - fp: 172.0000 - tn: 5032.0000 - fn: 167.0000 - accuracy: 0.9674 - precision: 0.9670 - recall: 0.9679 - auc: 0.9950 - val_loss: 0.2241 - val_tp: 285.0000 - val_fp: 19.0000 - val_tn: 285.0000 - val_fn: 19.0000 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9688

# %%
cnn.plot_history()

# %%
cnn.get_classification_report(test_set)
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.76      0.91      0.83       234
#    PNEUMONIA       0.94      0.83      0.88       390
#
#     accuracy                           0.86       624
#    macro avg       0.85      0.87      0.85       624
# weighted avg       0.87      0.86      0.86       624

# %%
cnn.display_confusion_matrix(test_set)
