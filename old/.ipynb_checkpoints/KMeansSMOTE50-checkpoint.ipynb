# %%
import numpy as np 
import matplotlib.pyplot as plt 
import os
from PIL import Image
print(os.listdir("./common/data"))

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
tf.compat.v1.keras.backend.set_session(tf.compat.v1.Session(config=config))

# Keras Libraries
import keras
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator, load_img
from sklearn.metrics import classification_report, confusion_matrix
# %matplotlib inline
# Out:
# ['chest_xray', 'resampled', 'TEST']
# Using TensorFlow backend.

# %% [markdown]
# # Resample Data Into New Dataset

# %% [markdown]
# # Resample Train Data

# %%
from common.src import resample as res

# %%
from imblearn.over_sampling import KMeansSMOTE

path = r'C:\Users\mmitk\dev\2020\pneumonia\common\data\chest_xray\train'
SM = KMeansSMOTE(random_state=0)

# %%
res.resample_directory(SM, path, 'KmeansSMOTE', val = False)

# %% [markdown]
# # Load Data

# %%
train_folder= './common/data/resampled/KmeansSMOTE/train'
val_folder = './common/data/chest_xray/val/'
test_folder = './common/data/chest_xray/test/'

# %% [markdown]
# Set up Training Folders

# %%
# train 
os.listdir(train_folder)
train_n = train_folder+'NORMAL/'
train_p = train_folder+'PNEUMONIA/'

# %% [markdown]
# Set up Testing Folders

# %%
# test
os.listdir(test_folder)
train_n = test_folder+'NORMAL/'
train_p = test_folder+'PNEUMONIA/'

# %% [markdown]
# # Generate Dataset from image data

# %%
from common.src import util

train_datagen = util.create_train_datagen()
test_datagen = util.create_test_datagen()

training_set = util.create_generator_set(train_datagen, './common/data/resampled/KmeansSMOTE/train')
validation_generator = util.create_generator_set(test_datagen, './common/data/chest_xray/val/')
test_set = util.create_generator_set(test_datagen, './common/data/chest_xray/test/', batch_size = 1, shuffle = False)
# Out:
# Found 7750 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %% [markdown]
# # Create Model

# %%
from common.src import models

cnn = models.CNNModel(patience_s=49)
cnn.create_model()
cnn.summary()

# %% [markdown]
# # Fit Model

# %%
cnn_model = cnn.fit_generator(training_set, validation_generator, epochs=50)
# Out:
# Epoch 1/50
# 163/163 [==============================] - 17s 104ms/step - loss: 0.2882 - tp: 4492.0000 - fp: 710.0000 - tn: 4480.0000 - fn: 698.0000 - accuracy: 0.8644 - precision: 0.8635 - recall: 0.8655 - auc: 0.9494 - val_loss: 0.3872 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.9023
# Epoch 2/50
# 163/163 [==============================] - 15s 92ms/step - loss: 0.1882 - tp: 4806.0000 - fp: 388.0000 - tn: 4802.0000 - fn: 384.0000 - accuracy: 0.9256 - precision: 0.9253 - recall: 0.9260 - auc: 0.9786 - val_loss: 0.3987 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9062
# Epoch 3/50
# 163/163 [==============================] - 14s 87ms/step - loss: 0.1690 - tp: 4884.0000 - fp: 322.0000 - tn: 4894.0000 - fn: 332.0000 - accuracy: 0.9373 - precision: 0.9381 - recall: 0.9363 - auc: 0.9821 - val_loss: 0.7375 - val_tp: 171.0000 - val_fp: 133.0000 - val_tn: 171.0000 - val_fn: 133.0000 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - val_auc: 0.7773
# Epoch 4/50
# 163/163 [==============================] - 14s 84ms/step - loss: 0.1587 - tp: 4878.0000 - fp: 338.0000 - tn: 4878.0000 - fn: 338.0000 - accuracy: 0.9352 - precision: 0.9352 - recall: 0.9352 - auc: 0.9847 - val_loss: 0.6120 - val_tp: 190.0000 - val_fp: 114.0000 - val_tn: 190.0000 - val_fn: 114.0000 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.8262
# Epoch 5/50
# 163/163 [==============================] - 15s 90ms/step - loss: 0.1436 - tp: 4882.0000 - fp: 312.0000 - tn: 4878.0000 - fn: 308.0000 - accuracy: 0.9403 - precision: 0.9399 - recall: 0.9407 - auc: 0.9873 - val_loss: 0.4484 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8496
# Epoch 6/50
# 163/163 [==============================] - 15s 89ms/step - loss: 0.1305 - tp: 4905.0000 - fp: 282.0000 - tn: 4908.0000 - fn: 285.0000 - accuracy: 0.9454 - precision: 0.9456 - recall: 0.9451 - auc: 0.9890 - val_loss: 0.5304 - val_tp: 190.0000 - val_fp: 114.0000 - val_tn: 190.0000 - val_fn: 114.0000 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.8281
# Epoch 7/50
# 163/163 [==============================] - 14s 87ms/step - loss: 0.1348 - tp: 4923.0000 - fp: 271.0000 - tn: 4919.0000 - fn: 267.0000 - accuracy: 0.9482 - precision: 0.9478 - recall: 0.9486 - auc: 0.9886 - val_loss: 0.5616 - val_tp: 190.0000 - val_fp: 114.0000 - val_tn: 190.0000 - val_fn: 114.0000 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.8281
# Epoch 8/50
# 163/163 [==============================] - 15s 91ms/step - loss: 0.1121 - tp: 4971.0000 - fp: 216.0000 - tn: 4974.0000 - fn: 219.0000 - accuracy: 0.9581 - precision: 0.9584 - recall: 0.9578 - auc: 0.9919 - val_loss: 0.7387 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.7930
# Epoch 9/50
# 163/163 [==============================] - 15s 90ms/step - loss: 0.1301 - tp: 4959.0000 - fp: 262.0000 - tn: 4954.0000 - fn: 257.0000 - accuracy: 0.9502 - precision: 0.9498 - recall: 0.9507 - auc: 0.9896 - val_loss: 0.6814 - val_tp: 190.0000 - val_fp: 114.0000 - val_tn: 190.0000 - val_fn: 114.0000 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.7891
# Epoch 10/50
# 163/163 [==============================] - 13s 83ms/step - loss: 0.1107 - tp: 4965.0000 - fp: 222.0000 - tn: 4968.0000 - fn: 225.0000 - accuracy: 0.9569 - precision: 0.9572 - recall: 0.9566 - auc: 0.9921 - val_loss: 0.3732 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.9043
# Epoch 11/50
# 163/163 [==============================] - 14s 84ms/step - loss: 0.1190 - tp: 4979.0000 - fp: 235.0000 - tn: 4981.0000 - fn: 237.0000 - accuracy: 0.9548 - precision: 0.9549 - recall: 0.9546 - auc: 0.9912 - val_loss: 0.7026 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8242
# Epoch 12/50
# 163/163 [==============================] - 14s 86ms/step - loss: 0.1127 - tp: 4943.0000 - fp: 221.0000 - tn: 4943.0000 - fn: 221.0000 - accuracy: 0.9572 - precision: 0.9572 - recall: 0.9572 - auc: 0.9918 - val_loss: 0.4198 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8926
# Epoch 13/50
# 163/163 [==============================] - 15s 90ms/step - loss: 0.1081 - tp: 5013.0000 - fp: 201.0000 - tn: 5015.0000 - fn: 203.0000 - accuracy: 0.9613 - precision: 0.9614 - recall: 0.9611 - auc: 0.9926 - val_loss: 0.7054 - val_tp: 190.0000 - val_fp: 114.0000 - val_tn: 190.0000 - val_fn: 114.0000 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.8203
# Epoch 14/50
# 163/163 [==============================] - 14s 88ms/step - loss: 0.1057 - tp: 4970.0000 - fp: 220.0000 - tn: 4970.0000 - fn: 220.0000 - accuracy: 0.9576 - precision: 0.9576 - recall: 0.9576 - auc: 0.9927 - val_loss: 0.6064 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8535
# Epoch 15/50
# 163/163 [==============================] - 14s 84ms/step - loss: 0.1005 - tp: 5035.0000 - fp: 185.0000 - tn: 5031.0000 - fn: 181.0000 - accuracy: 0.9649 - precision: 0.9646 - recall: 0.9653 - auc: 0.9930 - val_loss: 0.3111 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9375
# Epoch 16/50
# 163/163 [==============================] - 14s 87ms/step - loss: 0.0986 - tp: 4992.0000 - fp: 195.0000 - tn: 4995.0000 - fn: 198.0000 - accuracy: 0.9621 - precision: 0.9624 - recall: 0.9618 - auc: 0.9935 - val_loss: 0.2427 - val_tp: 285.0000 - val_fp: 19.0000 - val_tn: 285.0000 - val_fn: 19.0000 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9609
# Epoch 17/50
# 163/163 [==============================] - 13s 82ms/step - loss: 0.1030 - tp: 5011.0000 - fp: 207.0000 - tn: 5009.0000 - fn: 205.0000 - accuracy: 0.9605 - precision: 0.9603 - recall: 0.9607 - auc: 0.9931 - val_loss: 0.4379 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8867
# Epoch 18/50
# 163/163 [==============================] - 14s 87ms/step - loss: 0.0971 - tp: 4994.0000 - fp: 195.0000 - tn: 4995.0000 - fn: 196.0000 - accuracy: 0.9623 - precision: 0.9624 - recall: 0.9622 - auc: 0.9939 - val_loss: 0.2812 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9336
# Epoch 19/50
# 163/163 [==============================] - 14s 83ms/step - loss: 0.1016 - tp: 4990.0000 - fp: 200.0000 - tn: 4990.0000 - fn: 200.0000 - accuracy: 0.9615 - precision: 0.9615 - recall: 0.9615 - auc: 0.9934 - val_loss: 0.4425 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8672
# Epoch 20/50
# 163/163 [==============================] - 14s 89ms/step - loss: 0.0909 - tp: 5011.0000 - fp: 177.0000 - tn: 5013.0000 - fn: 179.0000 - accuracy: 0.9657 - precision: 0.9659 - recall: 0.9655 - auc: 0.9949 - val_loss: 0.2795 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9492
# Epoch 21/50
# 163/163 [==============================] - 14s 86ms/step - loss: 0.0820 - tp: 5061.0000 - fp: 152.0000 - tn: 5064.0000 - fn: 155.0000 - accuracy: 0.9706 - precision: 0.9708 - recall: 0.9703 - auc: 0.9956 - val_loss: 0.7715 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8398
# Epoch 22/50
# 163/163 [==============================] - 14s 85ms/step - loss: 0.0864 - tp: 5023.0000 - fp: 159.0000 - tn: 5031.0000 - fn: 167.0000 - accuracy: 0.9686 - precision: 0.9693 - recall: 0.9678 - auc: 0.9948 - val_loss: 0.5545 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8555
# Epoch 23/50
# 163/163 [==============================] - 13s 81ms/step - loss: 0.0852 - tp: 5020.0000 - fp: 167.0000 - tn: 5023.0000 - fn: 170.0000 - accuracy: 0.9675 - precision: 0.9678 - recall: 0.9672 - auc: 0.9951 - val_loss: 0.7933 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8438
# Epoch 24/50
# 163/163 [==============================] - 14s 85ms/step - loss: 0.0887 - tp: 5036.0000 - fp: 184.0000 - tn: 5032.0000 - fn: 180.0000 - accuracy: 0.9651 - precision: 0.9648 - recall: 0.9655 - auc: 0.9951 - val_loss: 0.4324 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8906
# Epoch 25/50
# 163/163 [==============================] - 13s 81ms/step - loss: 0.0846 - tp: 5018.0000 - fp: 173.0000 - tn: 5017.0000 - fn: 172.0000 - accuracy: 0.9668 - precision: 0.9667 - recall: 0.9669 - auc: 0.9951 - val_loss: 0.3182 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9414
# Epoch 26/50
# 163/163 [==============================] - 14s 85ms/step - loss: 0.0905 - tp: 5037.0000 - fp: 176.0000 - tn: 5040.0000 - fn: 179.0000 - accuracy: 0.9660 - precision: 0.9662 - recall: 0.9657 - auc: 0.9948 - val_loss: 0.4948 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8613
# Epoch 27/50
# 163/163 [==============================] - 13s 80ms/step - loss: 0.0871 - tp: 5017.0000 - fp: 169.0000 - tn: 5021.0000 - fn: 173.0000 - accuracy: 0.9671 - precision: 0.9674 - recall: 0.9667 - auc: 0.9951 - val_loss: 0.2476 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9844
# Epoch 28/50
# 163/163 [==============================] - 13s 79ms/step - loss: 0.0743 - tp: 5071.0000 - fp: 146.0000 - tn: 5070.0000 - fn: 145.0000 - accuracy: 0.9721 - precision: 0.9720 - recall: 0.9722 - auc: 0.9962 - val_loss: 1.0135 - val_tp: 190.0000 - val_fp: 114.0000 - val_tn: 190.0000 - val_fn: 114.0000 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.7715
# Epoch 29/50
# 163/163 [==============================] - 13s 78ms/step - loss: 0.0885 - tp: 5021.0000 - fp: 169.0000 - tn: 5021.0000 - fn: 169.0000 - accuracy: 0.9674 - precision: 0.9674 - recall: 0.9674 - auc: 0.9942 - val_loss: 1.0214 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.7734
# Epoch 30/50
# 163/163 [==============================] - 13s 78ms/step - loss: 0.0760 - tp: 5051.0000 - fp: 142.0000 - tn: 5048.0000 - fn: 139.0000 - accuracy: 0.9729 - precision: 0.9727 - recall: 0.9732 - auc: 0.9961 - val_loss: 0.4118 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.9141
# Epoch 31/50
# 163/163 [==============================] - 13s 81ms/step - loss: 0.0928 - tp: 5019.0000 - fp: 175.0000 - tn: 5015.0000 - fn: 171.0000 - accuracy: 0.9667 - precision: 0.9663 - recall: 0.9671 - auc: 0.9941 - val_loss: 0.5694 - val_tp: 209.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 95.0000 - val_accuracy: 0.7188 - val_precision: 0.7333 - val_recall: 0.6875 - val_auc: 0.8574
# Epoch 32/50
# 163/163 [==============================] - 13s 79ms/step - loss: 0.0746 - tp: 5074.0000 - fp: 141.0000 - tn: 5075.0000 - fn: 142.0000 - accuracy: 0.9729 - precision: 0.9730 - recall: 0.9728 - auc: 0.9956 - val_loss: 0.2749 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9609
# Epoch 33/50
# 163/163 [==============================] - 13s 77ms/step - loss: 0.0840 - tp: 5023.0000 - fp: 168.0000 - tn: 5022.0000 - fn: 167.0000 - accuracy: 0.9677 - precision: 0.9676 - recall: 0.9678 - auc: 0.9954 - val_loss: 0.2314 - val_tp: 266.0000 - val_fp: 19.0000 - val_tn: 285.0000 - val_fn: 38.0000 - val_accuracy: 0.9062 - val_precision: 0.9333 - val_recall: 0.8750 - val_auc: 0.9766
# Epoch 34/50
# 163/163 [==============================] - 13s 81ms/step - loss: 0.0770 - tp: 5041.0000 - fp: 150.0000 - tn: 5040.0000 - fn: 149.0000 - accuracy: 0.9712 - precision: 0.9711 - recall: 0.9713 - auc: 0.9954 - val_loss: 0.1483 - val_tp: 285.0000 - val_fp: 19.0000 - val_tn: 285.0000 - val_fn: 19.0000 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9961
# Epoch 35/50
# 163/163 [==============================] - 13s 78ms/step - loss: 0.0718 - tp: 5072.0000 - fp: 144.0000 - tn: 5072.0000 - fn: 144.0000 - accuracy: 0.9724 - precision: 0.9724 - recall: 0.9724 - auc: 0.9963 - val_loss: 0.2448 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9707
# Epoch 36/50
# 163/163 [==============================] - 14s 84ms/step - loss: 0.0797 - tp: 5036.0000 - fp: 150.0000 - tn: 5040.0000 - fn: 154.0000 - accuracy: 0.9707 - precision: 0.9711 - recall: 0.9703 - auc: 0.9954 - val_loss: 0.3250 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9258
# Epoch 37/50
# 163/163 [==============================] - 13s 78ms/step - loss: 0.0718 - tp: 5080.0000 - fp: 139.0000 - tn: 5077.0000 - fn: 136.0000 - accuracy: 0.9736 - precision: 0.9734 - recall: 0.9739 - auc: 0.9964 - val_loss: 0.5323 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8555
# Epoch 38/50
# 163/163 [==============================] - 13s 79ms/step - loss: 0.0914 - tp: 4986.0000 - fp: 177.0000 - tn: 4987.0000 - fn: 178.0000 - accuracy: 0.9656 - precision: 0.9657 - recall: 0.9655 - auc: 0.9945 - val_loss: 0.5903 - val_tp: 209.0000 - val_fp: 114.0000 - val_tn: 190.0000 - val_fn: 95.0000 - val_accuracy: 0.6562 - val_precision: 0.6471 - val_recall: 0.6875 - val_auc: 0.8477
# Epoch 39/50
# 163/163 [==============================] - 13s 83ms/step - loss: 0.0611 - tp: 5101.0000 - fp: 110.0000 - tn: 5106.0000 - fn: 115.0000 - accuracy: 0.9784 - precision: 0.9789 - recall: 0.9780 - auc: 0.9976 - val_loss: 0.1846 - val_tp: 304.0000 - val_fp: 0.0000e+00 - val_tn: 304.0000 - val_fn: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 40/50
# 163/163 [==============================] - 12s 76ms/step - loss: 0.0698 - tp: 5052.0000 - fp: 134.0000 - tn: 5056.0000 - fn: 138.0000 - accuracy: 0.9738 - precision: 0.9742 - recall: 0.9734 - auc: 0.9960 - val_loss: 0.1955 - val_tp: 266.0000 - val_fp: 19.0000 - val_tn: 285.0000 - val_fn: 38.0000 - val_accuracy: 0.9062 - val_precision: 0.9333 - val_recall: 0.8750 - val_auc: 0.9805
# Epoch 41/50
# 163/163 [==============================] - 13s 78ms/step - loss: 0.0807 - tp: 5057.0000 - fp: 152.0000 - tn: 5064.0000 - fn: 159.0000 - accuracy: 0.9702 - precision: 0.9708 - recall: 0.9695 - auc: 0.9950 - val_loss: 0.4332 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8867
# Epoch 42/50
# 163/163 [==============================] - 13s 80ms/step - loss: 0.0612 - tp: 5060.0000 - fp: 128.0000 - tn: 5062.0000 - fn: 130.0000 - accuracy: 0.9751 - precision: 0.9753 - recall: 0.9750 - auc: 0.9973 - val_loss: 0.3671 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9180
# Epoch 43/50
# 163/163 [==============================] - 13s 79ms/step - loss: 0.0718 - tp: 5057.0000 - fp: 137.0000 - tn: 5053.0000 - fn: 133.0000 - accuracy: 0.9740 - precision: 0.9736 - recall: 0.9744 - auc: 0.9966 - val_loss: 0.4694 - val_tp: 228.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 76.0000 - val_accuracy: 0.7812 - val_precision: 0.8000 - val_recall: 0.7500 - val_auc: 0.8906
# Epoch 44/50
# 163/163 [==============================] - 13s 81ms/step - loss: 0.0737 - tp: 5057.0000 - fp: 128.0000 - tn: 5062.0000 - fn: 133.0000 - accuracy: 0.9749 - precision: 0.9753 - recall: 0.9744 - auc: 0.9962 - val_loss: 0.4053 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9258
# Epoch 45/50
# 163/163 [==============================] - 13s 81ms/step - loss: 0.0688 - tp: 5081.0000 - fp: 137.0000 - tn: 5079.0000 - fn: 135.0000 - accuracy: 0.9739 - precision: 0.9737 - recall: 0.9741 - auc: 0.9970 - val_loss: 0.1986 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9727
# Epoch 46/50
# 163/163 [==============================] - 13s 81ms/step - loss: 0.0633 - tp: 5057.0000 - fp: 128.0000 - tn: 5062.0000 - fn: 133.0000 - accuracy: 0.9749 - precision: 0.9753 - recall: 0.9744 - auc: 0.9974 - val_loss: 0.4119 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8750
# Epoch 47/50
# 163/163 [==============================] - 15s 90ms/step - loss: 0.0708 - tp: 5064.0000 - fp: 126.0000 - tn: 5064.0000 - fn: 126.0000 - accuracy: 0.9757 - precision: 0.9757 - recall: 0.9757 - auc: 0.9958 - val_loss: 0.5683 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8672
# Epoch 48/50
# 163/163 [==============================] - 13s 80ms/step - loss: 0.0685 - tp: 5079.0000 - fp: 138.0000 - tn: 5078.0000 - fn: 137.0000 - accuracy: 0.9736 - precision: 0.9735 - recall: 0.9737 - auc: 0.9966 - val_loss: 0.3355 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.9355
# Epoch 49/50
# 163/163 [==============================] - 13s 80ms/step - loss: 0.0637 - tp: 5067.0000 - fp: 131.0000 - tn: 5059.0000 - fn: 123.0000 - accuracy: 0.9755 - precision: 0.9748 - recall: 0.9763 - auc: 0.9974 - val_loss: 0.3061 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9453 66.0000 - tn: 2814.0000 -
# Epoch 50/50
# 163/163 [==============================] - 13s 83ms/step - loss: 0.0767 - tp: 5076.0000 - fp: 139.0000 - tn: 5077.0000 - fn: 140.0000 - accuracy: 0.9733 - precision: 0.9733 - recall: 0.9732 - auc: 0.9960 - val_loss: 0.2608 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9492

# %%
cnn.plot_history()

# %%
cnn.get_classification_report(test_set)
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.97      0.81      0.88       234
#    PNEUMONIA       0.90      0.98      0.94       390
#
#     accuracy                           0.92       624
#    macro avg       0.93      0.90      0.91       624
# weighted avg       0.92      0.92      0.92       624

# %%
cnn.display_confusion_matrix(test_set)
