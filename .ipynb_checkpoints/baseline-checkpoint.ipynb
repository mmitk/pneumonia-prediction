# %%
import numpy as np 
import matplotlib.pyplot as plt 
import os
from PIL import Image
print(os.listdir("./common/data"))

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
tf.compat.v1.keras.backend.set_session(tf.compat.v1.Session(config=config))

# Keras Libraries
import keras
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator, load_img
from sklearn.metrics import classification_report, confusion_matrix
# %matplotlib inline
# Out:
# ['chest_xray', 'resampled', 'TEST']
# Using TensorFlow backend.

# %% [markdown]
# # Load Data

# %%
train_folder= './common/data/chest_xray/train/'
val_folder = './common/data/chest_xray/val/'
test_folder = './common/data/chest_xray/test/'

# %% [markdown]
# Set up Training Folders

# %%
# train 
os.listdir(train_folder)
train_n = train_folder+'NORMAL/'
train_p = train_folder+'PNEUMONIA/'

# %% [markdown]
# Set up Testing Folders

# %%
# test
os.listdir(test_folder)
train_n = test_folder+'NORMAL/'
train_p = test_folder+'PNEUMONIA/'

# %%
#Normal pic 
print(len(os.listdir(train_n)))
rand_norm= np.random.randint(0,len(os.listdir(train_n)))
norm_pic = os.listdir(train_n)[rand_norm]
print('normal picture title: ',norm_pic)

norm_pic_address = train_n+norm_pic

#Pneumonia
rand_p = np.random.randint(0,len(os.listdir(train_p)))

sic_pic =  os.listdir(train_p)[rand_norm]
sic_address = train_p+sic_pic
print('pneumonia picture title:', sic_pic)

# Load images
norm_load = Image.open(norm_pic_address)
sic_load = Image.open(sic_address)

# plot images
f = plt.figure(figsize= (10,6))
a1 = f.add_subplot(1,2,1)
img_plot = plt.imshow(norm_load)
a1.set_title('Normal')

a2 = f.add_subplot(1, 2, 2)
img_plot = plt.imshow(sic_load)
a2.set_title('Pneumonia')
# Out:
# 234
# normal picture title:  IM-0022-0001.jpeg
# pneumonia picture title: person104_bacteria_492.jpeg
# Text(0.5, 1.0, 'Pneumonia')

# %% [markdown]
# # Generate Dataset from image data

# %%
from common.src import util

train_datagen = util.create_train_datagen()
test_datagen = util.create_test_datagen()

training_set = util.create_generator_set(train_datagen, './common/data/chest_xray/train/')
validation_generator = util.create_generator_set(test_datagen, './common/data/chest_xray/val/')
test_set = util.create_generator_set(test_datagen, './common/data/chest_xray/test/')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %% [markdown]
# # Create/Load Model

# %%
from common.src import models

try:
    cnn = models.CNNModel(model = keras.models.load_model("./common/models/baselineE20.h5"))
    do_training = False
except:
    do_training = True
    cnn = models.CNNModel()
    cnn.create_model()
    cnn.summary()

# %% [markdown]
# # Fit Model

# %%
if do_training:
    cnn_model = cnn.fit_generator(training_set, validation_generator, epochs = 20)
# Out:
# Epoch 1/20
# 163/163 [==============================] - 214s 1s/step - loss: 0.3511 - tp: 4425.0000 - fp: 826.0000 - tn: 4390.0000 - fn: 791.0000 - accuracy: 0.8450 - precision: 0.8427 - recall: 0.8484 - auc: 0.9240 - val_loss: 0.6601 - val_tp: 6240.0000 - val_fp: 3744.0000 - val_tn: 6240.0000 - val_fn: 3744.0000 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.8086
# Epoch 2/20
# 163/163 [==============================] - 221s 1s/step - loss: 0.2264 - tp: 4722.0000 - fp: 491.0000 - tn: 4725.0000 - fn: 494.0000 - accuracy: 0.9056 - precision: 0.9058 - recall: 0.9053 - auc: 0.9690 - val_loss: 0.3213 - val_tp: 9360.0000 - val_fp: 624.0000 - val_tn: 9360.0000 - val_fn: 624.0000 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9375
# Epoch 3/20
# 163/163 [==============================] - 232s 1s/step - loss: 0.2077 - tp: 4774.0000 - fp: 424.0000 - tn: 4792.0000 - fn: 442.0000 - accuracy: 0.9170 - precision: 0.9184 - recall: 0.9153 - auc: 0.9737 - val_loss: 0.4484 - val_tp: 7488.0000 - val_fp: 2496.0000 - val_tn: 7488.0000 - val_fn: 2496.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8809
# Epoch 4/20
# 163/163 [==============================] - 228s 1s/step - loss: 0.1888 - tp: 4811.0000 - fp: 410.0000 - tn: 4806.0000 - fn: 405.0000 - accuracy: 0.9219 - precision: 0.9215 - recall: 0.9224 - auc: 0.9784 - val_loss: 1.0304 - val_tp: 5616.0000 - val_fp: 4368.0000 - val_tn: 5616.0000 - val_fn: 4368.0000 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - val_auc: 0.7891
# Epoch 5/20
# 163/163 [==============================] - 223s 1s/step - loss: 0.1742 - tp: 4856.0000 - fp: 362.0000 - tn: 4854.0000 - fn: 360.0000 - accuracy: 0.9308 - precision: 0.9306 - recall: 0.9310 - auc: 0.9812 - val_loss: 0.2496 - val_tp: 9984.0000 - val_fp: 624.0000 - val_tn: 9360.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9688 - val_precision: 0.9412 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 6/20
# 163/163 [==============================] - 234s 1s/step - loss: 0.1619 - tp: 4902.0000 - fp: 313.0000 - tn: 4903.0000 - fn: 314.0000 - accuracy: 0.9399 - precision: 0.9400 - recall: 0.9398 - auc: 0.9835 - val_loss: 0.3237 - val_tp: 8112.0000 - val_fp: 2496.0000 - val_tn: 7488.0000 - val_fn: 1872.0000 - val_accuracy: 0.7812 - val_precision: 0.7647 - val_recall: 0.8125 - val_auc: 0.9297
# Epoch 7/20
# 163/163 [==============================] - 219s 1s/step - loss: 0.1740 - tp: 4870.0000 - fp: 347.0000 - tn: 4869.0000 - fn: 346.0000 - accuracy: 0.9336 - precision: 0.9335 - recall: 0.9337 - auc: 0.9809 - val_loss: 0.2724 - val_tp: 8736.0000 - val_fp: 1248.0000 - val_tn: 8736.0000 - val_fn: 1248.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9688
# Epoch 8/20
# 163/163 [==============================] - 220s 1s/step - loss: 0.1491 - tp: 4929.0000 - fp: 283.0000 - tn: 4933.0000 - fn: 287.0000 - accuracy: 0.9454 - precision: 0.9457 - recall: 0.9450 - auc: 0.9861 - val_loss: 0.3401 - val_tp: 8736.0000 - val_fp: 1248.0000 - val_tn: 8736.0000 - val_fn: 1248.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9258
# Epoch 9/20
# 163/163 [==============================] - 230s 1s/step - loss: 0.1510 - tp: 4913.0000 - fp: 307.0000 - tn: 4909.0000 - fn: 303.0000 - accuracy: 0.9415 - precision: 0.9412 - recall: 0.9419 - auc: 0.9857 - val_loss: 0.3822 - val_tp: 7488.0000 - val_fp: 2496.0000 - val_tn: 7488.0000 - val_fn: 2496.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.9023
# Epoch 10/20
# 163/163 [==============================] - 200s 1s/step - loss: 0.1414 - tp: 4913.0000 - fp: 305.0000 - tn: 4911.0000 - fn: 303.0000 - accuracy: 0.9417 - precision: 0.9415 - recall: 0.9419 - auc: 0.9878 - val_loss: 0.7829 - val_tp: 6864.0000 - val_fp: 3120.0000 - val_tn: 6864.0000 - val_fn: 3120.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.7793
# Epoch 11/20
# 163/163 [==============================] - 199s 1s/step - loss: 0.1452 - tp: 4907.0000 - fp: 304.0000 - tn: 4912.0000 - fn: 309.0000 - accuracy: 0.9412 - precision: 0.9417 - recall: 0.9408 - auc: 0.9871 - val_loss: 1.0870 - val_tp: 6240.0000 - val_fp: 3744.0000 - val_tn: 6240.0000 - val_fn: 3744.0000 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.7695
# Epoch 12/20
# 163/163 [==============================] - 190s 1s/step - loss: 0.1292 - tp: 4961.0000 - fp: 256.0000 - tn: 4960.0000 - fn: 255.0000 - accuracy: 0.9510 - precision: 0.9509 - recall: 0.9511 - auc: 0.9894 - val_loss: 0.2462 - val_tp: 8736.0000 - val_fp: 1248.0000 - val_tn: 8736.0000 - val_fn: 1248.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9688
# Epoch 13/20
# 163/163 [==============================] - 205s 1s/step - loss: 0.1299 - tp: 4953.0000 - fp: 266.0000 - tn: 4950.0000 - fn: 263.0000 - accuracy: 0.9493 - precision: 0.9490 - recall: 0.9496 - auc: 0.9892 - val_loss: 0.3042 - val_tp: 8736.0000 - val_fp: 624.0000 - val_tn: 9360.0000 - val_fn: 1248.0000 - val_accuracy: 0.9062 - val_precision: 0.9333 - val_recall: 0.8750 - val_auc: 0.9570
# Epoch 14/20
# 163/163 [==============================] - 201s 1s/step - loss: 0.1096 - tp: 5003.0000 - fp: 218.0000 - tn: 4998.0000 - fn: 213.0000 - accuracy: 0.9587 - precision: 0.9582 - recall: 0.9592 - auc: 0.9925 - val_loss: 0.4546 - val_tp: 6240.0000 - val_fp: 3744.0000 - val_tn: 6240.0000 - val_fn: 3744.0000 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.8516
# Epoch 15/20
# 163/163 [==============================] - 217s 1s/step - loss: 0.1179 - tp: 4982.0000 - fp: 235.0000 - tn: 4981.0000 - fn: 234.0000 - accuracy: 0.9550 - precision: 0.9550 - recall: 0.9551 - auc: 0.9909 - val_loss: 0.7548 - val_tp: 6240.0000 - val_fp: 3744.0000 - val_tn: 6240.0000 - val_fn: 3744.0000 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.8262
# Epoch 16/20
# 163/163 [==============================] - 215s 1s/step - loss: 0.1218 - tp: 4982.0000 - fp: 232.0000 - tn: 4984.0000 - fn: 234.0000 - accuracy: 0.9553 - precision: 0.9555 - recall: 0.9551 - auc: 0.9903 - val_loss: 0.3023 - val_tp: 8112.0000 - val_fp: 1872.0000 - val_tn: 8112.0000 - val_fn: 1872.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9453
# Epoch 17/20
# 163/163 [==============================] - 191s 1s/step - loss: 0.1243 - tp: 4968.0000 - fp: 253.0000 - tn: 4963.0000 - fn: 248.0000 - accuracy: 0.9520 - precision: 0.9515 - recall: 0.9525 - auc: 0.9904 - val_loss: 0.4075 - val_tp: 7488.0000 - val_fp: 2496.0000 - val_tn: 7488.0000 - val_fn: 2496.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8750
# Epoch 18/20
# 163/163 [==============================] - 223s 1s/step - loss: 0.1140 - tp: 4994.0000 - fp: 217.0000 - tn: 4999.0000 - fn: 222.0000 - accuracy: 0.9579 - precision: 0.9584 - recall: 0.9574 - auc: 0.9918 - val_loss: 1.5124 - val_tp: 6240.0000 - val_fp: 3744.0000 - val_tn: 6240.0000 - val_fn: 3744.0000 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.7070
# Epoch 19/20
# 163/163 [==============================] - 191s 1s/step - loss: 0.1166 - tp: 4982.0000 - fp: 241.0000 - tn: 4975.0000 - fn: 234.0000 - accuracy: 0.9545 - precision: 0.9539 - recall: 0.9551 - auc: 0.9913 - val_loss: 0.5427 - val_tp: 6864.0000 - val_fp: 3120.0000 - val_tn: 6864.0000 - val_fn: 3120.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8672
# Epoch 20/20
# 163/163 [==============================] - 211s 1s/step - loss: 0.1113 - tp: 5012.0000 - fp: 205.0000 - tn: 5011.0000 - fn: 204.0000 - accuracy: 0.9608 - precision: 0.9607 - recall: 0.9609 - auc: 0.9920 - val_loss: 0.6821 - val_tp: 6864.0000 - val_fp: 3120.0000 - val_tn: 6864.0000 - val_fn: 3120.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8125

# %%
#keras.models.save_model(cnn.model, "./common/models/baselineE20.hd5", overwrite=True, include_optimizer=True)
baseline_json = cnn.model.to_json()
with open ('./common/models/baselineE20arch.json','w') as js:
    js.write(baseline_json)

cnn.model.save_weights('./common/models/baselineE20weights.hd5')

# %%
cnn.plot_history()

# %%
print(cnn.get_classification_report(test_set))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.39      0.28      0.32       234
#    PNEUMONIA       0.63      0.74      0.68       390
#
#     accuracy                           0.56       624
#    macro avg       0.51      0.51      0.50       624
# weighted avg       0.54      0.56      0.55       624
#
# None

# %%
cnn.display_confusion_matrix(test_data_generator = test_set)

# %%
from common.src import models

# %%
from common.src import models 

with open('./common/models/baselineE20arch.json','r') as jtest:
    loaded_test = jtest.read()

cnnTest =  keras.models.model_from_json(loaded_test)
cnnTest.model.load_weights('./common/models/baselineE20weights.hd5')

#cnnTest = models.CNNModel(model = keras.models.load_model("./common/models/baselineE20"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-636b908295b6> in <module>
#       4     loaded_test = jtest.read()
#       5
# ----> 6 cnnTest = models.CNNModel(model = keras.models.model_from_json(loaded_test))
#       7 cnnTest.model.load_weights('./common/models/baselineE20weights.hd5')
#       8
#
# TypeError: __init__() got an unexpected keyword argument 'model'
