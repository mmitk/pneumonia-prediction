# %%
import numpy as np 
import matplotlib.pyplot as plt 
import os
from PIL import Image
print(os.listdir("./common/data"))

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
tf.compat.v1.keras.backend.set_session(tf.compat.v1.Session(config=config))

# Keras Libraries
import keras
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator, load_img
from sklearn.metrics import classification_report, confusion_matrix
# %matplotlib inline
# Out:
# ['chest_xray', 'resampled', 'TEST']
# Using TensorFlow backend.

# %% [markdown]
# # Resample Data Into New Dataset

# %% [markdown]
# # Resample Train Data

# %%
from common.src import resample as res

# %%
from imblearn.over_sampling import BorderlineSMOTE

path = r'C:\Users\mmitk\dev\2020\pneumonia\common\data\chest_xray\train'
SM = BorderlineSMOTE(random_state=0)

# %%
res.resample_directory(SM, path, 'borderlineSMOTE', val = False)
# Out:
# ----------[LOADING IMAGES]----------
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ......................
# Finished [LOADING IMAGES]
# ----------[RESAMPLING IMAGES]----------
#
# Finished [RESAMPLING IMAGES]
# ----------[WRITING RESAMPLED IMAGES]----------
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ...........................................................................
# Finished [RESAMPLING DIRECTORY]

# %% [markdown]
# # Load Data

# %%
train_folder= './common/data/resampled/borderlineSMOTE/train'
val_folder = './common/data/chest_xray/val/'
test_folder = './common/data/chest_xray/test/'

# %% [markdown]
# Set up Training Folders

# %%
# train 
os.listdir(train_folder)
train_n = train_folder+'NORMAL/'
train_p = train_folder+'PNEUMONIA/'

# %% [markdown]
# Set up Testing Folders

# %%
# test
os.listdir(test_folder)
train_n = test_folder+'NORMAL/'
train_p = test_folder+'PNEUMONIA/'

# %% [markdown]
# # Generate Dataset from image data

# %%
from common.src import util

train_datagen = util.create_train_datagen()
test_datagen = util.create_test_datagen()

training_set = util.create_generator_set(train_datagen, './common/data/resampled/borderlineSMOTE/train')
validation_generator = util.create_generator_set(test_datagen, './common/data/chest_xray/val/')
test_set = util.create_generator_set(test_datagen, './common/data/chest_xray/test/', batch_size = 1, shuffle = False)
# Out:
# Found 7750 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %% [markdown]
# # Create Model

# %%
from common.src import models

cnn = models.CNNModel(patience_s=19)
cnn.create_model()
cnn.summary()

# %% [markdown]
# # Fit Model

# %%
cnn_model = cnn.fit_generator(training_set, validation_generator, epochs=20)
# Out:
# Epoch 1/20
# 163/163 [==============================] - 12s 72ms/step - loss: 0.4323 - tp: 4122.0000 - fp: 1177.0000 - tn: 4013.0000 - fn: 1068.0000 - accuracy: 0.7837 - precision: 0.7779 - recall: 0.7942 - auc: 0.8761 - val_loss: 0.4165 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.9004
# Epoch 2/20
# 163/163 [==============================] - 10s 61ms/step - loss: 0.2158 - tp: 4762.0000 - fp: 453.0000 - tn: 4763.0000 - fn: 454.0000 - accuracy: 0.9131 - precision: 0.9131 - recall: 0.9130 - auc: 0.9718 - val_loss: 0.3521 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9258
# Epoch 3/20
# 163/163 [==============================] - 10s 61ms/step - loss: 0.2104 - tp: 4729.0000 - fp: 456.0000 - tn: 4734.0000 - fn: 461.0000 - accuracy: 0.9117 - precision: 0.9121 - recall: 0.9112 - auc: 0.9731 - val_loss: 0.7931 - val_tp: 190.0000 - val_fp: 114.0000 - val_tn: 190.0000 - val_fn: 114.0000 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.8203
# Epoch 4/20
# 163/163 [==============================] - 10s 61ms/step - loss: 0.1904 - tp: 4840.0000 - fp: 387.0000 - tn: 4829.0000 - fn: 376.0000 - accuracy: 0.9269 - precision: 0.9260 - recall: 0.9279 - auc: 0.9776 - val_loss: 0.3596 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9258
# Epoch 5/20
# 163/163 [==============================] - 10s 64ms/step - loss: 0.1634 - tp: 4853.0000 - fp: 344.0000 - tn: 4846.0000 - fn: 337.0000 - accuracy: 0.9344 - precision: 0.9338 - recall: 0.9351 - auc: 0.9835 - val_loss: 0.3761 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8945
# Epoch 6/20
# 163/163 [==============================] - 11s 66ms/step - loss: 0.1679 - tp: 4852.0000 - fp: 342.0000 - tn: 4848.0000 - fn: 338.0000 - accuracy: 0.9345 - precision: 0.9342 - recall: 0.9349 - auc: 0.9825 - val_loss: 0.2841 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9648
# Epoch 7/20
# 163/163 [==============================] - 10s 60ms/step - loss: 0.1476 - tp: 4899.0000 - fp: 318.0000 - tn: 4898.0000 - fn: 317.0000 - accuracy: 0.9391 - precision: 0.9390 - recall: 0.9392 - auc: 0.9866 - val_loss: 0.5030 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8359
# Epoch 8/20
# 163/163 [==============================] - 10s 64ms/step - loss: 0.1430 - tp: 4911.0000 - fp: 281.0000 - tn: 4909.0000 - fn: 279.0000 - accuracy: 0.9461 - precision: 0.9459 - recall: 0.9462 - auc: 0.9870 - val_loss: 0.6756 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8184
# Epoch 9/20
# 163/163 [==============================] - 10s 61ms/step - loss: 0.1308 - tp: 4910.0000 - fp: 278.0000 - tn: 4912.0000 - fn: 280.0000 - accuracy: 0.9462 - precision: 0.9464 - recall: 0.9461 - auc: 0.9891 - val_loss: 0.5113 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8477
# Epoch 10/20
# 163/163 [==============================] - 10s 60ms/step - loss: 0.1257 - tp: 4936.0000 - fp: 251.0000 - tn: 4939.0000 - fn: 254.0000 - accuracy: 0.9513 - precision: 0.9516 - recall: 0.9511 - auc: 0.9899 - val_loss: 0.3057 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9414
# Epoch 11/20
# 163/163 [==============================] - 10s 61ms/step - loss: 0.1307 - tp: 4922.0000 - fp: 274.0000 - tn: 4916.0000 - fn: 268.0000 - accuracy: 0.9478 - precision: 0.9473 - recall: 0.9484 - auc: 0.9893 - val_loss: 0.2665 - val_tp: 285.0000 - val_fp: 19.0000 - val_tn: 285.0000 - val_fn: 19.0000 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9492
# Epoch 12/20
# 163/163 [==============================] - 10s 62ms/step - loss: 0.1250 - tp: 4956.0000 - fp: 266.0000 - tn: 4950.0000 - fn: 260.0000 - accuracy: 0.9496 - precision: 0.9491 - recall: 0.9502 - auc: 0.9902 - val_loss: 0.5090 - val_tp: 209.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 95.0000 - val_accuracy: 0.7500 - val_precision: 0.7857 - val_recall: 0.6875 - val_auc: 0.8398
# Epoch 13/20
# 163/163 [==============================] - 10s 62ms/step - loss: 0.1109 - tp: 4965.0000 - fp: 220.0000 - tn: 4970.0000 - fn: 225.0000 - accuracy: 0.9571 - precision: 0.9576 - recall: 0.9566 - auc: 0.9923 - val_loss: 0.3545 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.9180
# Epoch 14/20
# 163/163 [==============================] - 10s 63ms/step - loss: 0.1279 - tp: 4938.0000 - fp: 254.0000 - tn: 4936.0000 - fn: 252.0000 - accuracy: 0.9513 - precision: 0.9511 - recall: 0.9514 - auc: 0.9896 - val_loss: 0.3448 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9297
# Epoch 15/20
# 163/163 [==============================] - 11s 65ms/step - loss: 0.1181 - tp: 4980.0000 - fp: 239.0000 - tn: 4977.0000 - fn: 236.0000 - accuracy: 0.9545 - precision: 0.9542 - recall: 0.9548 - auc: 0.9910 - val_loss: 0.2749 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9492
# Epoch 16/20
# 163/163 [==============================] - 10s 61ms/step - loss: 0.1212 - tp: 4978.0000 - fp: 236.0000 - tn: 4980.0000 - fn: 238.0000 - accuracy: 0.9546 - precision: 0.9547 - recall: 0.9544 - auc: 0.9907 - val_loss: 0.3597 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9121
# Epoch 17/20
# 163/163 [==============================] - 10s 60ms/step - loss: 0.1154 - tp: 4932.0000 - fp: 235.0000 - tn: 4929.0000 - fn: 232.0000 - accuracy: 0.9548 - precision: 0.9545 - recall: 0.9551 - auc: 0.9917 - val_loss: 0.3926 - val_tp: 228.0000 - val_fp: 76.0000 - val_tn: 228.0000 - val_fn: 76.0000 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8828
# Epoch 18/20
# 163/163 [==============================] - 10s 60ms/step - loss: 0.1198 - tp: 4965.0000 - fp: 248.0000 - tn: 4968.0000 - fn: 251.0000 - accuracy: 0.9522 - precision: 0.9524 - recall: 0.9519 - auc: 0.9909 - val_loss: 0.3229 - val_tp: 266.0000 - val_fp: 38.0000 - val_tn: 266.0000 - val_fn: 38.0000 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9453
# Epoch 19/20
# 163/163 [==============================] - 10s 60ms/step - loss: 0.1167 - tp: 4950.0000 - fp: 244.0000 - tn: 4946.0000 - fn: 240.0000 - accuracy: 0.9534 - precision: 0.9530 - recall: 0.9538 - auc: 0.9917 - val_loss: 0.5197 - val_tp: 209.0000 - val_fp: 95.0000 - val_tn: 209.0000 - val_fn: 95.0000 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8398
# Epoch 20/20
# 163/163 [==============================] - 10s 60ms/step - loss: 0.0959 - tp: 5016.0000 - fp: 196.0000 - tn: 5020.0000 - fn: 200.0000 - accuracy: 0.9620 - precision: 0.9624 - recall: 0.9617 - auc: 0.9943 - val_loss: 0.3856 - val_tp: 247.0000 - val_fp: 57.0000 - val_tn: 247.0000 - val_fn: 57.0000 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9102

# %%
cnn.plot_history()

# %%
cnn.get_classification_report(test_set)
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.77      0.78      0.78       234
#    PNEUMONIA       0.87      0.86      0.87       390
#
#     accuracy                           0.83       624
#    macro avg       0.82      0.82      0.82       624
# weighted avg       0.83      0.83      0.83       624

# %%
cnn.display_confusion_matrix(test_set)
